# %% [markdown]
# Use 3d spatio-temporal conv kernels.

# %%
import torch
import torch.nn as nn
import torch.utils.data as Data
import torchvision
from torch.nn import functional as F
from torch.autograd import Variable

import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set(color_codes=True)
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import h5py
import cv2
from scipy.stats import pearsonr#Pearson correlation coefficient
from sklearn.decomposition import randomized_svd
from scipy.signal import find_peaks
import scipy.optimize as opt

#import tensorly as tl#use tensorly to do tensor decompostion
#from tensorly.decomposition import parafac
#tl.set_backend('numpy') # or any other backend

import datetime
import time
#import winsound#sound alarm when code finishes, only in windows

# for auto-reloading external modules
# %load_ext autoreload
# %autoreload 2

# %%
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(1)

torch.backends.cudnn.deterministic=True
np.random.seed(1)
torch.manual_seed(1)    # reproducible

# %%
# for plot figures
plt.rcParams.update({'figure.max_open_warning': 0})
#Output matplotlib figure to SVG with text as text, not curves
plt.rcParams['svg.fonttype'] = 'none'
# axis spine
#use it like: adjust_spines(ax, ['left', 'bottom'])
def adjust_spines(ax, spines):
    for loc, spine in ax.spines.items():
        if loc in spines:
            spine.set_position(('outward', 2))  # outward by 2 points
            #spine.set_smart_bounds(True)
        else:
            spine.set_color('none')  # don't draw spine
    # turn off ticks where there is no spine
    if 'left' in spines:
        ax.yaxis.set_ticks_position('left')
    else:
        # no yaxis ticks
        ax.yaxis.set_ticks([])
    if 'bottom' in spines:
        ax.xaxis.set_ticks_position('bottom')
    else:
        # no xaxis ticks
        ax.xaxis.set_ticks([])

# %%
training_inputs = np.load('../data/fig3_training_inputs.npy')
training_set = np.load('../data/fig3_training_set.npy')
test_inputs = np.load('../data/fig3_test_inputs.npy')
test_set = np.load('../data/fig3_test_set.npy')

# %%
#split original training data into two parts, training loader: 2200, validation loader: 200
#make the dataset suitable for pytorch
train_loader=[]
for ii in range(0,2200,110):
    temp0=training_inputs[ii:ii+110] -0.5 #center the stimulus
    temp1=training_set[ii:ii+110]#100*200(neurons)
    temp=(temp0,temp1)
    train_loader.append(temp)

temp0=training_inputs[2200:] -0.5 #center the stimulus
temp1=training_set[2200:]#200*200(neurons)
val_loader=(temp0,temp1)

temp0=np.copy(test_inputs) -0.5 #center the stimulus
temp1=np.copy(test_set)#50*200(neurons)
test_loader=(temp0,temp1)

print ('length of train_loader:')
print (len(train_loader))
print ('shape of train_loader[0][0]:')
print (train_loader[0][0].shape)
print ('shape of train_loader[0][1]:')
print (train_loader[0][1].shape)
print ('shape of val_loader[0]:')
print (val_loader[0].shape)
print ('shape of val_loader[1]:')
print (val_loader[1].shape)
print ('shape of test_loader[0]:')
print (test_loader[0].shape)
print ('shape of test_loader[1]:')
print (test_loader[1].shape)
# Out:
# length of train_loader:
# 20
# shape of train_loader[0][0]:
# (110, 2, 8, 28, 28)
# shape of train_loader[0][1]:
# (110, 96)
# shape of val_loader[0]:
# (200, 2, 8, 28, 28)
# shape of val_loader[1]:
# (200, 96)
# shape of test_loader[0]:
# (50, 2, 8, 28, 28)
# shape of test_loader[1]:
# (50, 96)

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=1, ncols=10,figsize=(12.5,2.5))
for ii in range(10):
    axes[ii].imshow(train_loader[0][0][ii][0][0],cmap='gray',vmin=-0.5,vmax=0.5)
    axes[ii].grid(False)#axes[ii,jj].axis('tight')

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=5, ncols=1,figsize=(10,5))
for ii in range(5):
    axes[ii].plot(train_loader[0][1][:,ii])

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=1, ncols=10,figsize=(12.5,2.5))
for ii in range(10):
    axes[ii].imshow(test_loader[0][ii][0][0],cmap='gray',vmin=-0.5,vmax=0.5)
    axes[ii].grid(False)#axes[ii,jj].axis('tight')

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=5, ncols=1,figsize=(10,5))
for ii in range(5):
    axes[ii].plot(test_loader[1][:,ii])
    #axes[ii].grid(False)#axes[ii,jj].axis('tight')

# %%
#some help function
def bce_loss(input, target):
    """
    Numerically stable version of the binary cross-entropy loss function.

    As per https://github.com/pytorch/pytorch/issues/751
    See the TensorFlow docs for a derivation of this formula:
    https://www.tensorflow.org/api_docs/python/tf/nn/sigmoid_cross_entropy_with_logits

    Inputs:
    - input: PyTorch Tensor of shape (N, ) giving scores.
    - target: PyTorch Tensor of shape (N,) containing 0 and 1 giving targets.

    Returns:
    - A PyTorch Tensor containing the mean BCE loss over the minibatch of input data.
    """
    neg_abs = - input.abs()
    loss = input.clamp(min=0) - input * target + (1 + neg_abs.exp()).log()
    return loss.mean()

class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size() # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

class Unflatten(nn.Module):
    """
    An Unflatten module receives an input of shape (N, C*H*W) and reshapes it
    to produce an output of shape (N, C, H, W).
    """
    def __init__(self, N=-1, C=128, H=7, W=7):
        super(Unflatten, self).__init__()
        self.N = N
        self.C = C
        self.H = H
        self.W = W
    def forward(self, x):
        return x.view(self.N, self.C, self.H, self.W)

class Flatten3D(nn.Module):
    def forward(self, x):
        N, C, D, H, W = x.size() # read in N, C, D, H, W
        return x.view(N, -1)  # "flatten" the C *D* H * W values into a single vector per image

class Unflatten3D(nn.Module):
    """
    An Unflatten module receives an input of shape (N, C*D*H*W) and reshapes it
    to produce an output of shape (N, C, D,H, W).
    """
    def __init__(self, N=-1, C=128, D=7, H=7, W=7):
        super(Unflatten3D, self).__init__()
        self.N = N
        self.C = C
        self.D = D
        self.H = H
        self.W = W
    def forward(self, x):
        return x.view(self.N, self.C, self.D, self.H, self.W)
    
    
def initialize_weights(m):
    if isinstance(m, nn.Linear) or isinstance(m, nn.ConvTranspose2d):
        init.xavier_uniform_(m.weight.data)
def init_weights_Kaiming(m):
    if type(m) == nn.Linear or type(m) == nn.Conv3d or type(m) == nn.ConvTranspose3d\
    or type(m) == nn.Conv2d or type(m) == nn.ConvTranspose2d:
        #torch.nn.init.kaiming_normal_(m.weight)
        torch.nn.init.kaiming_uniform_(m.weight)

def loss_vae(recon_x, x, mu, logvar):
    tempN=x.shape[0]
    MSE = F.mse_loss(recon_x, x, reduction='sum')
    #BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction='sum')
    # see Appendix B from VAE paper:
    # Kingma and Welling. Auto-Encoding Variational Bayes. ICLR, 2014
    # https://arxiv.org/abs/1312.6114
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    #return BCE + KLD
    return (MSE + KLD)/(tempN*10*2*56*56)#batch size tempN, to be comparable with other ae variants loss

loss_mse = nn.MSELoss()
#loss_ssim = pytorch_ssim.SSIM(window_size=3)

#loss with L2 and L1 regularizer
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def loss_L2L1(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempN=x.shape[0]
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    L1loss=beta*F.l1_loss(beta_y,torch.zeros_like(beta_y),reduction='sum')
    return (MSE+L2loss+L1loss)/(tempN*10*2*56*56)#batch size tempN, to be comparable with other ae variants loss

#loss with L2 and L1 regularizer, version2
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def loss_L2L1v2(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempC, tempD, tempH, tempW =x.size()
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    B, C, D, H, W = beta_y.size() # Batch*channel*depth*height*width
    temp1=beta_y.view(B,C,-1)
    temp2=torch.norm(temp1,p=2,dim=2)
    temp3=torch.sum(torch.abs(temp2))
    L1loss=beta*temp3
    #return (MSE+L2loss+L1loss)/(tempB* 2*10*12*12)#batch size tempN, to be comparable with other ae variants loss
    return (MSE+L2loss+L1loss)/(tempB* tempC* tempD* tempH* tempW)#to be comparable with other ae variants loss

#loss with L2 and L1 regularizer, for supervised encoded
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def loss_L2L1_SE(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempN =x.size()
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    return (MSE+L2loss+L1loss)/(tempB* tempN)
#loss with L2 and L1 regularizer, for supervised encoded, Poisson loss
#something like loss = Poissonloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def Ploss_L2L1_SE(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempN =x.size()
    Ploss = F.poisson_nll_loss(recon_x, x,log_input=False, reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    return (Ploss+L2loss+L1loss)/(tempB* tempN)
def Ploss_L2L1_SE2(recon_x, x, alpha, alpha2, beta, alpha_x, alpha_x2, beta_y): #different convkernels with different L2 penalty
    tempB, tempN =x.size()
    Ploss = F.poisson_nll_loss(recon_x, x,log_input=False, reduction='sum')
    #
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    #
    l2temp2=0.0
    for temp in alpha_x2:
        l2temp2 = l2temp2 + temp.weight.norm(2)
    L2loss2=alpha2*l2temp2
    #
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    return (Ploss+L2loss+L2loss2+L1loss)/(tempB* tempN)
def Ploss_L2L1_SE_ST(recon_x, x, alpha1, alpha2, beta, alpha_x1, alpha_x2, beta_y): # for spatial and temporal separable model
    tempB, tempN =x.size()
    Ploss = F.poisson_nll_loss(recon_x, x,log_input=False, reduction='sum')
    l2temp=0.0
    for temp in alpha_x1:
        l2temp = l2temp+ temp.norm(2)
    l2temp2=0.0
    for temp in alpha_x2:
        l2temp2 = l2temp2+ temp.norm(2)
    L2loss=alpha1*l2temp+alpha2*l2temp2
    #
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    #return (Ploss+L2loss+L1loss)/(tempB* tempN)
    return Ploss+L2loss+L1loss
def loss_L1L1_SE(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempN =x.size()
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(1)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    return (MSE+L2loss+L1loss)/(tempB* tempN)

#loss with L2 and L1 regularizer, for supervised encoded, L2 for conv kernel smoothness
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def loss_L2lapL1_SE(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempN =x.size()
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    laplacian=torch.tensor([[0.5,1.0,0.5],[1.0,-6.0,1.0],[0.5,1.0,0.5]], requires_grad=False)#laplacian kernel
    for temp in alpha_x:
        #l2temp = l2temp+ temp.weight.norm(2)
        NN,CC=temp.weight.shape[0],temp.weight.shape[1]
        laplacians=laplacian.repeat(CC, CC, 1, 1).requires_grad_(False).to(device)
        temp2=F.conv2d(temp.weight,laplacians)
        l2temp = l2temp+ temp2.norm(2)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    return (MSE+L2loss+L1loss)/(tempB* tempN)

#visualize DNN
#https://github.com/chongyangma/cs231n/blob/master/assignments/assignment3/NetworkVisualization-PyTorch.ipynb
#https://blog.keras.io/how-convolutional-neural-networks-see-the-world.html
#https://jacobgil.github.io/deeplearning/filter-visualizations
#https://towardsdatascience.com/how-to-visualize-convolutional-features-in-40-lines-of-code-70b7d87b0030
#simple version: compute the gradient of the output channel wrt a blank image
#complex version: performa gradient ascend on the target channel, start with noise image
def vis_model_fl(model,device,xxshape):#visualize for final layer
    model=model.to(device)
    for param in model.parameters():
        param.requires_grad=False
    model=model.eval()
    (tempB,tempC,tempH,tempW)=xxshape#tempB should be equal to 1
    #xx=torch.randn((tempB,tempC,tempH,tempW),requires_grad=True)
    xx=torch.zeros((tempB,tempC,tempH,tempW),requires_grad=True)
    if xx.grad is not None:
        xx.grad.data.zero_()
    out=model(xx)
    outlen=out.shape[1]
    yy=torch.zeros(outlen,tempC,tempH,tempW)
    for ii in range(outlen):
        if xx.grad is not None:
            xx.grad.data.zero_()
        out=model(xx)
        temp=out[0,ii]
        temp.backward()
        yy[ii]=xx.grad.data
        #if xx.grad is not None:
        #    xx.grad.data.zero_()
    return yy
def vis_model_fl_3d(model,device,xxshape):#visualize for final layer
    model=model.to(device)
    for param in model.parameters():
        param.requires_grad=False
    model=model.eval()
    (tempB,tempC,tempD,tempH,tempW)=xxshape#tempB should be equal to 1
    #xx=torch.randn((tempB,tempC,tempH,tempW),requires_grad=True)
    xx=torch.zeros((tempB,tempC,tempD,tempH,tempW),requires_grad=True)
    if xx.grad is not None:
        xx.grad.data.zero_()
    out=model(xx)
    outlen=out.shape[1]
    yy=torch.zeros(outlen,tempC,tempD,tempH,tempW)
    for ii in range(outlen):
        if xx.grad is not None:
            xx.grad.data.zero_()
        out=model(xx)
        temp=out[0,ii]
        temp.backward()
        yy[ii]=xx.grad.data
        #if xx.grad is not None:
        #    xx.grad.data.zero_()
    return yy

#different preprocessing for different models
#x.shape: batchsize*10*2*56*56, x: bg, 1.0
#model: the model to be used, region: upper visual field (sky) or lower visual field (ground)
#region: sky or ground data
#pre_method: different preprocessing method, 'center': minus channel_mean, 'normalize': minus channel_mean then divided by
# the channel_std
def preprocess_np(x,model,pre_method,region):
    '''
    #some preprocessing if using model 'AutoEncoder3D_2'
    if model.__class__.__name__=='AutoEncoder3D_1':
        return x
    #for ae3D_2 or ae3D_3, subtrated by luminance mean value of each frame
    if model.__class__.__name__=='AutoEncoder3D_2' or \
        model.__class__.__name__=='AutoEncoder3D_3':
        for ii in range(x.shape[0]):
            for jj in range(x.shape[1]):
                for kk in range(x.shape[2]):
                    x[ii,jj,kk,:,:]=x[ii,jj,kk,:,:]-np.mean(x[ii,jj,kk,:,:])
        return x
    '''
    #for ae3D_4, subtrated by luminance mean value in color channel seperately across all frames
    #then divided by std. Because of memory proplem, this is done in make_dataset.py
    #std here actually is 'normalized' std
    if pre_method=='normalize' and region=='sky':
        x[:,0,:,:,:]=(x[:,0,:,:,:]-sky_bg_mean_f[0])/sky_bg_std_f[0]
        x[:,1,:,:,:]=(x[:,1,:,:,:]-sky_bg_mean_f[1])/sky_bg_std_f[1]
        return x
    if pre_method=='normalize' and region=='ground':
        x[:,0,:,:,:]=(x[:,0,:,:,:]-ground_bg_mean_f[0])/ground_bg_std_f[0]
        x[:,1,:,:,:]=(x[:,1,:,:,:]-ground_bg_mean_f[1])/ground_bg_std_f[1]
        return x
    #center the data, subtrated by luminance mean value in color channel seperately across all frames
    if pre_method=='center' and region=='sky':
        x[:,0,:,:,:]=x[:,0,:,:,:]-sky_bg_mean_f[0]
        x[:,1,:,:,:]=x[:,1,:,:,:]-sky_bg_mean_f[1]
        return x
    if pre_method=='center' and region=='ground':
        x[:,0,:,:,:]=x[:,0,:,:,:]-ground_bg_mean_f[0]
        x[:,1,:,:,:]=x[:,1,:,:,:]-ground_bg_mean_f[1]
        return x

#https://discuss.pytorch.org/t/where-is-the-noise-layer-in-pytorch/2887/4
'''
class GaussianNoise(nn.Module):
    def __init__(self, stddev=0.1):
        super().__init__()
        self.stddev = stddev

    def forward(self, din):
        if self.training:
            #return din + torch.autograd.Variable(torch.randn(din.size()).cuda() * self.stddev)
            return din + torch.autograd.Variable(torch.randn(din.size()).cuda() * self.stddev)
        return din
'''
class GaussianNoise(nn.Module):
    def __init__(self, sigma=0.1, is_relative_detach=True):
        super().__init__()
        self.sigma = sigma
        self.is_relative_detach = is_relative_detach
        #self.noise = torch.tensor(0).to(device)
        #self.noise = torch.randn_like(input, dtype=None, device=device, requires_grad=False)

    def forward(self, x):
        if self.training and self.sigma != 0:
            #scale = self.sigma * x.detach() if self.is_relative_detach else self.sigma * x
            #sampled_noise = self.noise.repeat(*x.size()).normal_() * scale
            sampled_noise = torch.randn(x.size(),requires_grad=False).to(device)* self.sigma
            x = x + sampled_noise
        return x

# %%
#function for training,(alpha,beta) for L2L1v2 regularizer
def model_train(model,data,optimizer,device,EPOCH,loss_func,valdata,alpha=None,beta=None,alpha2=None,\
                earlystop=False,verbose=True):
    print(datetime.datetime.now())
    #model=model.to(device)
    #model=model.train()
    loss=0.0
    trainlosses=np.zeros((EPOCH))
    vallosses  =np.zeros((EPOCH)) # save validation losses of all epochs until early stopping
    for epoch in range(EPOCH):
        model=model.to(device)
        model=model.train()
        for step, (x,y) in enumerate(data):
            #some preprocessing
            #x=preprocess_np(x,model,pre_method,region)
            x=torch.from_numpy(x).float()
            y=torch.from_numpy(y).float()
            b_x = x.to(device) 
            b_y = y.to(device)
            if 'dn' in model.__class__.__name__:
                b_x=b_x+0.05*torch.randn(b_x.size()).to(device)
                b_x=torch.clamp(b_x,min=-1.0,max=1.0)
            elif 'vae' in model.__class__.__name__:
                encoded, mu, logvar, decoded = model(b_x)
                loss = loss_func(decoded, b_y, mu, logvar)
            elif 'L2L1' in model.__class__.__name__:
                encoded = model(b_x)
                loss=loss_func(decoded, b_y,alpha,beta,[model.conv1],encoded)
            elif 'ST' in model.__class__.__name__: # spatial and temporal kernel separable
                encoded = model(b_x)
                loss=loss_func(encoded, b_y,alpha,alpha2,beta,[model.conv1_ss],[model.conv1_st],[model.fc1])
            else:
                encoded = model(b_x)
                loss=loss_func(encoded, b_y,alpha,beta,[model.conv1],[model.fc1])
            
            #last epoch to get the training loss, keep the same sample size as validation
            trainlosses[epoch]=trainlosses[epoch]+loss.detach().clone().cpu().data.numpy()
            #
            optimizer.zero_grad()               # clear gradients for this training step
            loss.backward()                     # backpropagation, compute gradients
            optimizer.step()                    # apply gradients
            #
            if step % 100 == 0 and verbose==True:
                print('Model: ',model.__class__.__name__,'|Epoch: ', epoch,\
                      '| train loss: %.4f' % loss.cpu().data.numpy())
        #one epoch done
        #scheduler.step()
        if epoch>20 and earlystop==True: # early stopping check after each epoch, use CC as a metric
            temploss=model_val(model,valdata,1,device)
            vallosses[epoch]=temploss
            if epoch-np.argmax(vallosses)>4: # >4
                break
        #test
        trainlosses[epoch] =trainlosses[epoch]/len(data)
        temploss=model_val(model,valdata,1,device)
        vallosses[epoch]=temploss
    print ('Epoch: {:} val loss: {:.4f}, finish training!'.format(epoch,vallosses[epoch]))
    print(datetime.datetime.now())
    return trainlosses,vallosses #semilosses #test
    #print ('finish training!')
    #print(datetime.datetime.now())
    #train_loss=train_loss/len(data) #train_loader_length
    #print ('Model: ',model.__class__.__name__,'|train loss: %.4f' % train_loss)
    #return train_loss
    #winsound.Beep(400, 3000)#sound alarm when code finishes, freq=400, duration=3000ms
    
#_=model_train(ae3D_4,'normalize',sky',train_loader_shuffle,optimizer,device,EPOCH,loss_mse)

# %%
#use the trained model to test the validation loss
#show one example results
#val_eg: the example used to show results
#val_num: the number of validation dataset, when using gpu, may have memory problem, then set it small
def model_val(model,data,val_eg,device,loss_func=None):
    model=model.to(device)
    model=model.eval()
    #    
    #mse as metric,compute validation loss
    #loss_mse = nn.MSELoss()
    (x,y)=data
    x=torch.from_numpy(x).float()
    #y=torch.from_numpy(y).float()
    b_x = x.to(device) 
    #b_y = y.to(device)
    with torch.no_grad():
        if 'dn' in model.__class__.__name__:
            b_x=b_x+0.05*torch.randn(b_x.size()).to(device)
            b_x=torch.clamp(b_x,min=-1.0,max=1.0)
        if 'vae' in model.__class__.__name__:
            encoded, mu, logvar, decoded = model(b_x)
            #val_loss = loss_func(decoded, b_y, mu, logvar)
        else:
            encoded = model(b_x)
    #CC as metric
    encoded_np=encoded.cpu().data.numpy()
    valcc,valpV=pearsonr(encoded_np.T.flatten(), y.T.flatten())
    if valpV>0.05:
        valcc=0
    #Poisson loss metric
    #y=torch.from_numpy(y).float()
    #b_y = y.to(device)
    #valcc = F.poisson_nll_loss(encoded, b_y,log_input=False, reduction='sum')
    
    #encoded_np=encoded.cpu().data.numpy()
    #valcc,_=pearsonr(encoded_np.flatten(), y.flatten())
    #print ('Model: ',model.__class__.__name__,'|validation cc: %.4f' % valcc)
    #show one example
    #fig,ax=plt.subplots(nrows=1, ncols=1,figsize=(10,2))
    #ax.plot(data[1][:,val_eg],color='r',label='Target')
    #ax.plot(encoded.cpu().data.numpy()[:,val_eg],color='g',label='Predict')
    #ax.legend(loc='best',fontsize=12)
    return valcc
  
#_=model_val(ae3D_4,'normalize','sky',val_loader_shuffle_sky,200,1000,device_cpu,loss_mse)

# %%
#function: visualize conv0 weights
def Vis_conv3d_0(conv3d_0,temptitle,save=False,filename=None): # conv3d_0.shape (16, 2, 8, 9, 9)
    (outd,_,_,_,_)=conv3d_0.shape
    fig, axes = plt.subplots(nrows=3, ncols=outd,figsize=(outd, 3))
    for jj in range(outd):
        nt = 8 # time lag
        ny = 9
        nx = 9
        dims = [nt, ny, nx]
        [sRF_UV, tRF_UV]=mySVD(conv3d_0[jj,0], dims)
        [sRF_G, tRF_G]=mySVD(conv3d_0[jj,1], dims)
        tempmax=np.max(np.abs([sRF_UV,sRF_G]))
        axes[0,jj].imshow(sRF_UV,vmin=-tempmax,vmax=tempmax,cmap='bwr')
        axes[0,jj].set_xticks([])
        axes[0,jj].set_yticks([])
        axes[0,jj].set_title('%d' %(jj))
        axes[1,jj].imshow(sRF_G,vmin=-tempmax,vmax=tempmax,cmap='bwr')
        axes[1,jj].set_xticks([])
        axes[1,jj].set_yticks([])
        axes[2,jj].plot(tRF_G,color='g')
        axes[2,jj].plot(tRF_UV,color='purple')
        axes[2,jj].axhline(y=0,color='k')
        axes[2,jj].spines['left'].set_visible(False)
        axes[2,jj].spines['bottom'].set_visible(False)
        axes[2,jj].spines['right'].set_visible(False)
        axes[2,jj].spines['top'].set_visible(False)
        axes[2,jj].set_xticks([])
        axes[2,jj].set_yticks([])
        axes[0,0].set_ylabel(str(temptitle))
        axes[0,0].set_title('%d_UV' %(0))
    if save==True:
        fig.savefig(filename)

# %%
#using pearson correlation as metric
def model_test(model,data,device,use_pad0_sti=True):
    model=model.to(device)
    model=model.eval()
    (x,y)=data
    x=torch.from_numpy(x).float()
    b_x = x.to(device) 
    encoded = model(b_x)
    encoded_np=encoded.cpu().data.numpy()
    if use_pad0_sti==False: # do not use reponses of 0-padding stimulus, here 7 because we use 8 time lags
        encoded_np=encoded_np[7:,:]
        y=y[7:,:]
    testcc,testpvalue=pearsonr(encoded_np.flatten(), y.flatten())
    #show the best example
    testccs=np.zeros(y.shape[1])
    encoded_np=encoded_np+1e-5 #in case all zeros
    for ii in range(len(testccs)):
        testccs[ii],_=pearsonr(encoded_np[:,ii], y[:,ii])
    testccs[np.isnan(testccs)] = 0 #nan to 0
    test_best=np.argmax(testccs)
    fig,ax=plt.subplots(nrows=1, ncols=1,figsize=(10,2))
    ax.plot(y[:,test_best],'o',color='r',linestyle='-',alpha=0.5,label='Target')
    ax.plot(encoded_np[:,test_best],'o',color='g',linestyle='-',alpha=0.5,label='Predict')
    ax.legend(loc='best',fontsize=12)
    print ('Overall pearson correlation coefficient: ',testcc, ' and p-value: ',testpvalue)
    return testcc,testpvalue
    
#model_test(ae3D_4,'normalize',sky',test_loader_shuffle,2000,device,loss_mse)

# %%
device=torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device_cpu=torch.device('cpu')
#device=torch.device('cpu')
# 超参数
EPOCH = 50
BATCH_SIZE = 100
#LR = 0.05#original
LR=0.0001
L2=0.0#L2=0.000001#L2 regularization

# %%
# save svd results of all neuronal RFs
nt = 8 # time lag
ny = 28
nx = 28
dims = [nt, ny, nx]
def mySVD(w, dims):
    """
    SVD for 3d or 2d kernels
    only apply to Gaussian or DOG kernel, the center RF is near the frame center
    """
    if len(dims) == 3:
        dims_tRF = dims[0]
        dims_sRF = dims[1:]
        w_old=np.copy(w)
        w=np.reshape(w,(dims_tRF, np.prod(dims_sRF)))
        # Data matrix X, centered X
        w=w-np.mean(w,axis=0)
        U, S, Vt = randomized_svd(w, 3)
        sRF = Vt[0].reshape(*dims_sRF)
        tRF = U[:, 0]
        #change the sign of sRF and tRF to map with 3d RFs, which is unpredicable in SVD
        '''
        tempcc,_=pearsonr(sRF.flatten(), w[-2])
        if tempcc<0:
            sRF = -1 * sRF
            tRF = -1 * tRF
        '''
        '''
        #keep sRF and w[-2] the same scale
        sRF = np.max(w[-2])/np.max(sRF) *sRF
        tRF = np.max(sRF)/np.max(w[-2]) *tRF
        '''
        '''
        tempscale=np.max(np.abs(w[-2]))/np.max(np.abs(sRF))
        sRF = tempscale *sRF
        neww=np.einsum('i,jk->ijk',tRF,sRF)
        tempscale=np.max(w)/np.max(neww)
        tRF = tempscale *tRF
        '''
        '''
        tempscale=np.max(np.abs(w[-2]))/np.max(np.abs(sRF))
        sRF = tempscale *sRF
        tRF = tempscale *tRF
        '''
        peaks, _ = find_peaks(np.abs(tRF)) #peak index
        if not peaks.size>0: # empty array, no peaks
            peak_close2t0=-2 #this may not be the best way to visualize a RF
        else:
            peak_close2t0=peaks[-1] #peak index close to time point 0
        w_old_peak_blur=cv2.GaussianBlur(w_old[peak_close2t0],(5,5),0)
        sRF_blur=cv2.GaussianBlur(sRF,(5,5),0)
        #sRF, same polarity and magnitude as w_ol
        tempcc,_=pearsonr(sRF_blur.flatten(), w_old_peak_blur.flatten())
        if tempcc<0:
            sRF = -1 * sRF
        tempscale=np.max(np.abs(w_old_peak_blur))/np.max(np.abs(sRF_blur))
        sRF = tempscale *sRF
        #tRF
        #tRF = tempscale *tRF
        #if -np.min(w_old_peak_blur)>np.max(w_old_peak_blur) and tRF[peak_close2t0]>0: #w_old: off, tRF: on
        #    tRF = -1 *tRF
        #elif -np.min(w_old_peak_blur)<np.max(w_old_peak_blur) and tRF[peak_close2t0]<0: #w_old: on, tRF: off
        #    tRF = -1 *tRF
        if tempcc<0:
            tRF = -1 * tRF
    else:
        sRF = w
        tRF = None
    return [sRF, tRF]

# %%
class Fit_2dGaussian():
    """
    fitting to 2d Gaussian and measure the fitting goodness
    input_data: input y-values, 1d array
    data_shape: raw data shape, tuple, e.g. for a 9x9 RF of a neuron: (9,9)
    
    if fail to fit, r2=0; if the parametre sigma_x or sigma_y > the size of the RF(9), then r2=0
    
    #https://stackoverflow.com/questions/21566379/fitting-a-2d-gaussian-function-using-scipy-optimize-curve-fit-valueerror-and-m
    #https://stackoverflow.com/questions/19189362/getting-the-r-squared-value-using-curve-fit
    #https://stackoverflow.com/questions/29003241/how-to-quantitatively-measure-goodness-of-fit-in-scipy
    
    test examples:
        #define model function and pass independant variables x and y as a list
        def twoD_Gaussian(xydata_tuple, amplitude, xo, yo, sigma_x, sigma_y, theta, offset):
            (x, y) = xydata_tuple 
            xo = float(xo)
            yo = float(yo)    
            a = (np.cos(theta)**2)/(2*sigma_x**2) + (np.sin(theta)**2)/(2*sigma_y**2)
            b = -(np.sin(2*theta))/(4*sigma_x**2) + (np.sin(2*theta))/(4*sigma_y**2)
            c = (np.sin(theta)**2)/(2*sigma_x**2) + (np.cos(theta)**2)/(2*sigma_y**2)
            g = offset + amplitude*np.exp( - (a*((x-xo)**2) + 2*b*(x-xo)*(y-yo) 
                            + c*((y-yo)**2)))
            return g.ravel()
        # Create x and y indices
        x = np.arange(9)
        x,y = np.meshgrid(x, x)
        #create data
        data = twoD_Gaussian((x, y), 2, 4, 4, 3, 5, 0, 1)
        data_noisy = data + 0.02*np.random.normal(size=data.shape)
        #
        fit_2dgaussian=Fit_2dGaussian(data_noisy,(9,9))
        fit_2dgaussian.fit()
        fit_2dgaussian.plot()
        print (fit_2dgaussian.cal_r2())
    
    """
    def __init__(self,input_data,data_shape):
        super().__init__()
        self.input_data=input_data
        self.data_shape=data_shape
        #
        self.sigma_thresh=max(self.data_shape) # threshold of sigma after fitting
        self.data_fitted=None
        self.fit_sucess=None # indicate the success of failure of fit
        self.popt=None
        self.large_sigma=None # indicate the sigma_x or sigma_y is too large
    
    def _twoD_Gaussian(self,xydata_tuple, amplitude, xo, yo, sigma_x, sigma_y, theta, offset):
        """define model function and pass independant variables x and y as a list.
        The output of twoD_Gaussian needs to be 1D
        """
        (x, y) = xydata_tuple 
        xo = float(xo)
        yo = float(yo)    
        a = (np.cos(theta)**2)/(2*sigma_x**2) + (np.sin(theta)**2)/(2*sigma_y**2)
        b = -(np.sin(2*theta))/(4*sigma_x**2) + (np.sin(2*theta))/(4*sigma_y**2)
        c = (np.sin(theta)**2)/(2*sigma_x**2) + (np.cos(theta)**2)/(2*sigma_y**2)
        g = offset + amplitude*np.exp( - (a*((x-xo)**2) + 2*b*(x-xo)*(y-yo) 
                            + c*((y-yo)**2)))
        return g.ravel()

    def _fitting_r2(self,y,y_fit):
        """
        Use coefficient of determination (aka the R2 value) to measure goodness-of-fit
        y refers to your input y-values, y_fit refers to your fitted y-values. Both are 1d arrays
    
        """
        # residual sum of squares
        ss_res = np.sum((y - y_fit) ** 2)
        # total sum of squares
        ss_tot = np.sum((y - np.mean(y)) ** 2)
        # r-squared
        r2 = 1 - (ss_res / ss_tot)
        return r2
    
    def fit(self):
        """
        fitting
        in case of failing to fit:
        #https://stackoverflow.com/questions/9172574/scipy-curve-fit-runtime-error-stopping-iteration
        """
        x=np.arange(self.data_shape[0])
        y=np.arange(self.data_shape[1])
        x,y = np.meshgrid(x, y)
        #
        initial_guess = (1,int(self.data_shape[0]/2),int(self.data_shape[1]/2),\
                         int(self.data_shape[0]/2),int(self.data_shape[1]/2),0,1)
        #popt, pcov = opt.curve_fit(self._twoD_Gaussian, (x, y), self.input_data, p0=initial_guess)
        #self.data_fitted = self._twoD_Gaussian((x, y), *popt)
        #self.fit_sucess=False
        try:
            popt,pcov = opt.curve_fit(self._twoD_Gaussian, (x, y), self.input_data, p0=initial_guess)
        except RuntimeError:
            self.fit_sucess=False
        else:
            self.popt=popt
            self.data_fitted = self._twoD_Gaussian((x, y), *popt)
            self.fit_sucess=True
            if self.popt[-3]>self.sigma_thresh or self.popt[-4]>self.sigma_thresh:
                self.large_sigma=True
        return None
    
    def plot(self):
        """
        Plot the fitting result
        """
        if self.fit_sucess==True:
            x=np.arange(self.data_shape[0])
            y=np.arange(self.data_shape[1])
            x,y = np.meshgrid(x, y)
            fig, ax = plt.subplots(1, 1)
            ax.imshow(np.reshape(self.input_data,self.data_shape))
            ax.contour(x, y, np.reshape(self.data_fitted,self.data_shape), 3, colors='w')
        elif self.fit_sucess==False:
            print ('Fail to fit, no plot!')
    
    def cal_r2(self):
        """
        calculate r2 - goodness of fitting
        """
        if self.fit_sucess==True:
            if self.large_sigma==True:
                return 0
            else:
                return self._fitting_r2(self.input_data,self.data_fitted)
        elif self.fit_sucess==False:
            return 0

# %% [markdown]
# ##  <font color='red'>ModelSE3d1_Exp, conv 3d</font>
# 16 conv kernels 9x9

# %%
class ModelSE3d1_Exp(nn.Module):
    def __init__(self):
        super().__init__()
        self.numoffea=16 #number of features
        self.sizeoffea=20*20 #size of feature
        self.numofneuron=96 #number of neurons
        self.conv1=nn.Conv3d(2,self.numoffea,kernel_size=(8,9,9),stride=1)#16,20*20
        self.fc1=nn.Linear(self.numoffea*self.sizeoffea,self.numofneuron)

    def forward(self, x):
        encoded = F.relu(self.conv1(x)) #16,20*20
        encoded = encoded.view(-1,self.numoffea*self.sizeoffea)
        encoded = torch.exp(self.fc1(encoded))
        return encoded

# %%
#ModelSE3d1_Neu150_ST_Exp(), Poisson loss
EPOCH=100
LR = 2e-4
alphas=[0.0,1e0,1e1,1e2,1e3]
betas =[0.0,1/64,1/16,1/4,1] #[0.0,1/64,1/16,1/4,1.0]
modeltrainloss=[]
modelvalloss=[]
for ii in range(len(alphas)):
    for jj in range(len(betas)):
        modelname=str(ii*len(betas)+jj+1)
        torch.manual_seed(1)    # reproducible
        torch.cuda.manual_seed(1)
        tempmodel = ModelSE3d1_Exp()
        optimizer = torch.optim.Adam(tempmodel.parameters(), lr=LR,weight_decay=0.0)
        temp=model_train(tempmodel,train_loader,optimizer,device,EPOCH,Ploss_L2L1_SE,valdata=val_loader,\
                             alpha=alphas[ii],beta=betas[jj],alpha2=None,earlystop=True,verbose=True)
        modeltrainloss.append(temp)
        torch.save(tempmodel.state_dict(),\
                       './out/20200429_v5_ModelSE3d1_Exp_Ploss_'+modelname+'.pth')
        temp=model_val(tempmodel,val_loader,1,device_cpu,loss_mse)
        modelvalloss.append(temp)
        #release gpu memory
        del tempmodel
        torch.cuda.empty_cache()
# Out:
# 2020-11-29 10:15:29.603821
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0141
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4158
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4026
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.3967
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.3961
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.3942
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.3926
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.3908
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.3888
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.3868
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.3845
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.3821
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.3794
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.3765
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3732
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3696
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3657
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3613
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3566
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3515
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3461
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3406
# Epoch: 21 val loss: 0.2266, finish training!
# 2020-11-29 10:15:37.197384
# 2020-11-29 10:15:37.431582
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0197
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4217
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4085
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4026
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4020
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4000
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.3984
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.3966
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.3947
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.3926
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.3904
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.3880
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.3853
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.3824
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3793
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3758
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3719
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3677
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3632
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3583
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3531
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3477
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3423
# Epoch: 22 val loss: 0.2284, finish training!
# 2020-11-29 10:15:43.478306
# 2020-11-29 10:15:43.720917
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0368
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4394
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4260
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4199
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4190
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4167
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4147
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4126
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4104
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4080
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4055
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4029
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4001
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.3971
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3939
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3905
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3868
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3829
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3788
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3744
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3698
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3651
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3602
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3554
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3506
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3461
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3419
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3379
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.3343
# Epoch: 28 val loss: 0.2263, finish training!
# 2020-11-29 10:15:51.660855
# 2020-11-29 10:15:51.926804
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.1048
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.5095
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4928
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4827
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4770
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4698
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4627
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4556
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4487
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4420
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4358
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4301
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4251
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4209
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4173
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4142
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4115
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4090
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4065
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4041
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4016
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3991
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3964
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3937
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3909
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3880
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3851
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3821
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.3791
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.3761
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.3732
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.3704
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.3678
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.3653
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.3630
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.3607
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.3586
# Epoch: 36 val loss: 0.2436, finish training!
# 2020-11-29 10:16:02.263000
# 2020-11-29 10:16:02.502565
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.3770
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.7772
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.7112
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.6470
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.5885
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5387
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5054
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4902
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4811
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4738
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4675
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4621
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4570
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4526
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4484
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4447
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4414
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4384
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4356
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4332
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4309
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4288
# Epoch: 21 val loss: 0.2259, finish training!
# 2020-11-29 10:16:07.968911
# 2020-11-29 10:16:08.215019
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0143
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4160
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4029
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.3969
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.3963
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.3944
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.3928
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.3910
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.3891
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.3870
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.3848
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.3824
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.3797
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.3768
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3736
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3701
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3662
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3619
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3572
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3522
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3468
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3413
# Epoch: 21 val loss: 0.2270, finish training!
# 2020-11-29 10:16:13.742203
# 2020-11-29 10:16:13.969329
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0200
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4219
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4088
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4028
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4022
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4003
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.3987
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.3969
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.3949
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.3929
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.3907
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.3883
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.3857
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.3828
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3797
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3762
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3724
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3683
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3638
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3589
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3538
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3485
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3431
# Epoch: 22 val loss: 0.2289, finish training!
# 2020-11-29 10:16:19.860686
# 2020-11-29 10:16:20.157330
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0370
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4396
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4263
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4201
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4192
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4169
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4150
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4129
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4106
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4083
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4058
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4032
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4004
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.3975
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3943
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3909
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3873
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3835
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3794
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3750
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3705
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3658
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3610
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3562
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3514
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3470
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3427
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3388
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.3352
# Epoch: 28 val loss: 0.2270, finish training!
# 2020-11-29 10:16:27.759300
# 2020-11-29 10:16:28.028755
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.1050
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.5097
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4930
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4829
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4772
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4700
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4630
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4559
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4490
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4423
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4361
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4305
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4255
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4213
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4177
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4146
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4120
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4095
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4071
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4047
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4022
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3997
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3971
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3944
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3916
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3888
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3859
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3829
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.3800
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.3770
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.3741
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.3714
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.3688
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.3663
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.3639
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.3617
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.3596
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.3577
# Epoch: 37 val loss: 0.2426, finish training!
# 2020-11-29 10:16:38.479673
# 2020-11-29 10:16:38.713248
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.3772
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.7775
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.7115
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.6473
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.5888
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5390
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5058
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4906
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4815
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4742
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4680
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4626
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4576
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4531
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4490
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4454
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4420
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4390
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4363
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4338
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4315
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4295
# Epoch: 21 val loss: 0.2260, finish training!
# 2020-11-29 10:16:44.166512
# 2020-11-29 10:16:44.445883
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0163
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4182
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4049
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.3990
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.3984
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.3965
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.3949
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.3932
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.3914
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.3894
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.3873
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.3851
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.3827
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.3800
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3771
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3740
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3705
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3666
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3624
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3578
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3529
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3478
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3425
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3373
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3322
# Epoch: 24 val loss: 0.2278, finish training!
# 2020-11-29 10:16:50.860938
# 2020-11-29 10:16:51.151551
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0219
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4241
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4108
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4049
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4043
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4024
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4008
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.3991
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.3972
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.3953
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.3932
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.3910
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.3886
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.3860
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3832
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3801
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3767
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3730
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3689
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3645
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3598
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3549
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3498
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3448
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3398
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3351
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3308
# Epoch: 26 val loss: 0.2269, finish training!
# 2020-11-29 10:16:58.058563
# 2020-11-29 10:16:58.325338
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0389
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4418
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4283
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4222
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4213
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4191
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4172
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4151
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4130
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4108
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4084
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4060
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4034
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4007
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3979
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3948
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3915
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3881
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3844
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3804
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3763
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3720
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3676
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3631
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3586
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3543
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3502
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3464
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.3428
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.3395
# Epoch: 29 val loss: 0.2309, finish training!
# 2020-11-29 10:17:06.234857
# 2020-11-29 10:17:06.472669
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.1070
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.5119
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4951
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4850
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4794
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4723
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4654
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4584
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4516
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4451
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4390
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4335
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4288
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4247
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4214
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4185
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4160
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4137
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4116
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4094
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4072
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4050
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4027
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4003
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3979
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3954
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3928
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3902
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.3875
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.3848
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.3821
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.3795
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.3771
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.3747
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.3725
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.3704
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.3685
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.3666
# Model:  ModelSE3d1_Exp |Epoch:  38 | train loss: 0.3649
# Epoch: 38 val loss: 0.2480, finish training!
# 2020-11-29 10:17:17.151593
# 2020-11-29 10:17:17.397465
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.3791
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.7797
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.7137
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.6497
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.5915
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5420
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5091
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4944
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4855
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4784
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4725
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4673
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4625
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4582
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4543
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4508
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4476
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4447
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4421
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4397
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4375
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4355
# Epoch: 21 val loss: 0.2266, finish training!
# 2020-11-29 10:17:22.929490
# 2020-11-29 10:17:23.138856
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0359
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4396
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4247
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4183
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4173
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4152
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4134
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4116
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4098
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4081
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4065
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4049
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4034
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4019
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4004
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3989
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3975
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3960
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3946
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3931
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3916
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3900
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3884
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3866
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3848
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3829
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3808
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3786
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.3762
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.3737
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.3711
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.3684
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.3657
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.3629
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.3601
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.3574
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.3547
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.3522
# Model:  ModelSE3d1_Exp |Epoch:  38 | train loss: 0.3498
# Model:  ModelSE3d1_Exp |Epoch:  39 | train loss: 0.3474
# Epoch: 39 val loss: 0.2656, finish training!
# 2020-11-29 10:17:34.156182
# 2020-11-29 10:17:34.406455
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0416
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4455
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4306
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4243
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4233
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4212
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4194
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4176
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4159
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4143
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4127
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4111
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4096
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4082
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4068
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4054
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4040
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4026
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4012
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3998
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3984
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3969
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3953
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3937
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3919
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3901
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3881
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3860
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.3837
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.3814
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.3790
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.3765
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.3740
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.3714
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.3689
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.3665
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.3641
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.3618
# Model:  ModelSE3d1_Exp |Epoch:  38 | train loss: 0.3596
# Model:  ModelSE3d1_Exp |Epoch:  39 | train loss: 0.3576
# Epoch: 39 val loss: 0.2701, finish training!
# 2020-11-29 10:17:45.348257
# 2020-11-29 10:17:45.593586
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0586
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4632
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4482
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4417
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4405
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4382
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4362
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4342
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4323
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4304
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4286
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4269
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4253
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4237
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4221
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4206
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4191
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4177
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4162
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4148
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4134
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4119
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4105
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4089
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.4073
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.4057
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.4040
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.4022
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.4003
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.3984
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.3965
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.3946
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.3927
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.3908
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.3890
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.3872
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.3855
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.3839
# Model:  ModelSE3d1_Exp |Epoch:  38 | train loss: 0.3823
# Model:  ModelSE3d1_Exp |Epoch:  39 | train loss: 0.3808
# Model:  ModelSE3d1_Exp |Epoch:  40 | train loss: 0.3793
# Model:  ModelSE3d1_Exp |Epoch:  41 | train loss: 0.3779
# Model:  ModelSE3d1_Exp |Epoch:  42 | train loss: 0.3765
# Epoch: 42 val loss: 0.2806, finish training!
# 2020-11-29 10:17:57.352148
# 2020-11-29 10:17:57.637287
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.1267
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.5333
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.5153
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.5052
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4997
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4928
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4863
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4798
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4737
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4680
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4629
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4585
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4549
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4521
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4499
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4481
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4466
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4452
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4440
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4428
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4417
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4406
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4395
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4385
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.4374
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.4364
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.4353
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.4342
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.4331
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.4319
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.4307
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.4295
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.4283
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.4271
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.4258
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.4246
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.4234
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.4222
# Model:  ModelSE3d1_Exp |Epoch:  38 | train loss: 0.4210
# Model:  ModelSE3d1_Exp |Epoch:  39 | train loss: 0.4199
# Model:  ModelSE3d1_Exp |Epoch:  40 | train loss: 0.4189
# Model:  ModelSE3d1_Exp |Epoch:  41 | train loss: 0.4178
# Model:  ModelSE3d1_Exp |Epoch:  42 | train loss: 0.4168
# Model:  ModelSE3d1_Exp |Epoch:  43 | train loss: 0.4159
# Model:  ModelSE3d1_Exp |Epoch:  44 | train loss: 0.4150
# Model:  ModelSE3d1_Exp |Epoch:  45 | train loss: 0.4141
# Model:  ModelSE3d1_Exp |Epoch:  46 | train loss: 0.4132
# Model:  ModelSE3d1_Exp |Epoch:  47 | train loss: 0.4124
# Model:  ModelSE3d1_Exp |Epoch:  48 | train loss: 0.4116
# Model:  ModelSE3d1_Exp |Epoch:  49 | train loss: 0.4108
# Model:  ModelSE3d1_Exp |Epoch:  50 | train loss: 0.4101
# Model:  ModelSE3d1_Exp |Epoch:  51 | train loss: 0.4094
# Model:  ModelSE3d1_Exp |Epoch:  52 | train loss: 0.4086
# Model:  ModelSE3d1_Exp |Epoch:  53 | train loss: 0.4080
# Model:  ModelSE3d1_Exp |Epoch:  54 | train loss: 0.4073
# Model:  ModelSE3d1_Exp |Epoch:  55 | train loss: 0.4067
# Model:  ModelSE3d1_Exp |Epoch:  56 | train loss: 0.4060
# Model:  ModelSE3d1_Exp |Epoch:  57 | train loss: 0.4054
# Model:  ModelSE3d1_Exp |Epoch:  58 | train loss: 0.4048
# Epoch: 58 val loss: 0.2883, finish training!
# 2020-11-29 10:18:14.355447
# 2020-11-29 10:18:14.608327
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.3988
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.8014
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.7355
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.6730
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.6169
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5701
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5407
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.5288
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.5219
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.5168
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.5126
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.5090
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.5056
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.5024
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4993
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4962
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4932
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4902
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4874
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4845
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4818
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4792
# Epoch: 21 val loss: 0.2287, finish training!
# 2020-11-29 10:18:20.147196
# 2020-11-29 10:18:20.393758
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.2327
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.6102
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.5589
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.5287
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.5073
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4891
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4732
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4584
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4429
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4208
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4042
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4014
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.3999
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.3996
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3995
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3994
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3994
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3993
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3993
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3993
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3993
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3993
# Epoch: 21 val loss: 0.2314, finish training!
# 2020-11-29 10:18:25.950257
# 2020-11-29 10:18:26.201936
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.2384
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.6162
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.5650
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.5351
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.5139
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4960
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4803
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4658
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4506
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4292
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4119
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4089
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4073
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4070
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4068
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4067
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4066
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4065
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4064
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4064
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4063
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4063
# Epoch: 21 val loss: 0.2314, finish training!
# 2020-11-29 10:18:31.762731
# 2020-11-29 10:18:32.063722
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.2554
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.6341
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.5833
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.5538
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.5332
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5158
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5008
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4869
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4726
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4529
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4326
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4288
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4266
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4257
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4250
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4244
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4238
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4232
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4226
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4220
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4215
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4209
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4204
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4199
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.4195
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.4190
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.4186
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.4182
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.4178
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.4175
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.4171
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.4168
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.4164
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.4161
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.4158
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.4155
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.4152
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.4149
# Model:  ModelSE3d1_Exp |Epoch:  38 | train loss: 0.4146
# Model:  ModelSE3d1_Exp |Epoch:  39 | train loss: 0.4144
# Model:  ModelSE3d1_Exp |Epoch:  40 | train loss: 0.4141
# Model:  ModelSE3d1_Exp |Epoch:  41 | train loss: 0.4139
# Model:  ModelSE3d1_Exp |Epoch:  42 | train loss: 0.4136
# Model:  ModelSE3d1_Exp |Epoch:  43 | train loss: 0.4134
# Model:  ModelSE3d1_Exp |Epoch:  44 | train loss: 0.4132
# Model:  ModelSE3d1_Exp |Epoch:  45 | train loss: 0.4130
# Epoch: 45 val loss: 0.2317, finish training!
# 2020-11-29 10:18:44.864317
# 2020-11-29 10:18:45.116234
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.3234
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.7048
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.6535
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.6231
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.6019
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5839
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5685
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.5548
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.5418
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.5281
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.5054
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4860
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4788
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4738
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4698
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4664
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4633
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4605
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4580
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4557
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4536
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4517
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4499
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4482
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.4466
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.4452
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.4438
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.4425
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.4413
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.4401
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.4391
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.4380
# Epoch: 31 val loss: 0.2319, finish training!
# 2020-11-29 10:18:53.642516
# 2020-11-29 10:18:53.870386
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.5956
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.9773
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.8913
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.8234
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.7699
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.7316
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.7136
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.7028
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.6921
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.6796
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.6646
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.6475
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.6299
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.6134
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.5988
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.5857
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.5750
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.5665
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.5586
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.5488
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.5279
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.5166
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.5104
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.5060
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.5024
# Epoch: 24 val loss: 0.2318, finish training!
# 2020-11-29 10:19:00.384271

# %%
temp2=np.reshape(np.array(modelvalloss),(5,5))
print (temp2)
print (np.max(temp2))
# Out:
# [[0.22660135 0.22843837 0.2262754  0.24364616 0.22591374]
#  [0.22697045 0.22885277 0.22700963 0.2425557  0.22599079]
#  [0.22778962 0.22690129 0.23092203 0.24797065 0.22655421]
#  [0.26555884 0.27005784 0.28062113 0.28833447 0.22868793]
#  [0.23138323 0.2313922  0.23174866 0.23188113 0.23182814]]
# 0.28833446640979593

# %%
#conv kernel
tempmodel= ModelSE3d1_Exp()
tempmodel.load_state_dict(torch.load('./out/20200429_v5_ModelSE3d1_Exp_Ploss_'+str(19)+'.pth'))
tempmodel=tempmodel.to(device_cpu)
#get parameters of model
#conv3d_0=ae3D_1_ground_127.encoder[0].weight.cpu().data.numpy()
conv3d_0=tempmodel.conv1.weight.cpu().data.numpy() #shape (32,2,8,9,9)
print (conv3d_0.shape)
temptitle=1
Vis_conv3d_0(conv3d_0,temptitle)
# Out:
# (16, 2, 8, 9, 9)

# %% [markdown]
# ### after hyperparameter tuning

# %%
EPOCH = 100
LR = 2e-4
seeds  = [1]
alphas=[1e2]
betas =[1/4] 
modeltrainloss=[]
modelvalloss=[]
for ii in range(len(seeds)):
    modelname=str(ii+1)
    torch.manual_seed(seeds[ii])    # reproducible
    torch.cuda.manual_seed(seeds[ii])
    tempmodel = ModelSE3d1_Exp()
    optimizer = torch.optim.Adam(tempmodel.parameters(), lr=LR,weight_decay=0.0)
    temp=model_train(tempmodel,train_loader,optimizer,device,EPOCH,Ploss_L2L1_SE,valdata=val_loader,\
                             alpha=alphas[0],beta=betas[0],alpha2=None,earlystop=True,verbose=True)
    modeltrainloss.append(temp)
    torch.save(tempmodel.state_dict(),\
                       './out/20200429_v5_ModelSE3d1_Exp_Ploss_seed_'+modelname+'.pth') 
    temp=model_val(tempmodel,val_loader,1,device_cpu,loss_mse)
    modelvalloss.append(temp)
    #release gpu memory
    del tempmodel
    torch.cuda.empty_cache()

# %%
#test model
modeltestloss=[]
for ii in range(10):
    modelname=str(ii+1)
    tempmodel= ModelSE3d1_Exp()
    tempmodel.load_state_dict(torch.load('./out/20200429_v5_ModelSE3d1_Exp_Ploss_seed_'+modelname+'.pth'))
    tempmodel=tempmodel.to(device_cpu)
    CC,_=model_test(tempmodel,test_loader,device_cpu,use_pad0_sti=False)
    modeltestloss.append(CC)

torch.cuda.empty_cache()
modeltestloss=np.array(modeltestloss)
print (modeltestloss)
print (np.mean(modeltestloss))
# Out:
# Overall pearson correlation coefficient:  0.5035795766889388  and p-value:  2.194728290275356e-264
# Overall pearson correlation coefficient:  0.47457599178982424  and p-value:  6.162846702619601e-231
# Overall pearson correlation coefficient:  0.4520967706594745  and p-value:  3.8142761700796936e-207
# Overall pearson correlation coefficient:  0.45722243982356814  and p-value:  2.0530590428010095e-212
# Overall pearson correlation coefficient:  0.4843160388578612  and p-value:  8.222743481576943e-242
# Overall pearson correlation coefficient:  0.48514190893344444  and p-value:  9.476037538933675e-243
# Overall pearson correlation coefficient:  0.4352917644654599  and p-value:  1.7206806443374776e-190
# Overall pearson correlation coefficient:  0.49082494277081173  and p-value:  2.811522070612374e-249
# Overall pearson correlation coefficient:  0.4656928507697495  and p-value:  2.541669662264106e-221
# Overall pearson correlation coefficient:  0.4721738801699812  and p-value:  2.618195220189201e-228
# [0.50357958 0.47457599 0.45209677 0.45722244 0.48431604 0.48514191
#  0.43529176 0.49082494 0.46569285 0.47217388]
# 0.47209161649291137

# %% [markdown]
# ### RFs and predictions

# %%
#save CCs
def model_test_save(model,data,device,use_pad0_sti=True):
    model=model.to(device)
    model=model.eval()
    (x,y)=data
    x=torch.from_numpy(x).float()
    b_x = x.to(device) 
    encoded = model(b_x)
    encoded_np=encoded.cpu().data.numpy()
    if use_pad0_sti==False: # do not use reponses of 0-padding stimulus, here 7 because we use 8 time lags
        encoded_np=encoded_np[7:,:]
        y=y[7:,:]
    testccs=np.zeros((encoded_np.shape[1]))
    for ii in range(encoded_np.shape[1]):
        testccs[ii],testpvalue=pearsonr(encoded_np[:,ii], y[:,ii])
    print (np.median(testccs))
    return testccs
#
tempmodel= ModelSE3d1_Exp()
tempmodel.load_state_dict(torch.load('./out/20200429_v5_ModelSE3d1_Exp_Ploss_seed_1.pth'))
tempmodel=tempmodel.to(device_cpu)
CCs=model_test_save(tempmodel,test_loader,device_cpu,use_pad0_sti=False)
#print (CCs.shape)
#print (CCs)
# Out:
# 0.42779785471984577

# %%
#conv kernel
tempmodel= ModelSE3d1_Exp()
tempmodel.load_state_dict(torch.load('./out/20200429_v5_ModelSE3d1_Exp_Ploss_seed_1.pth'))
tempmodel=tempmodel.to(device_cpu)
#get parameters of model
#conv3d_0=ae3D_1_ground_127.encoder[0].weight.cpu().data.numpy()
conv3d_0=tempmodel.conv1.weight.cpu().data.numpy() #shape (32,2,8,9,9)
print (conv3d_0.shape)
temptitle=1
Vis_conv3d_0(conv3d_0,temptitle,save=False,filename='out_result/20200429_ModelSE3d1_Exp_dorsal_conv0_v5.svg')
# Out:
# (16, 2, 8, 9, 9)

# %%
#Use non-linear least squares to fit a 2d Gaussian function to conv0 and then measure the goodness of fit by r2
conv1_ss_s=[]
r2_s=[]
seeds=np.arange(1,11)
width,height=9,9
nt = 8 # time lag
ny = 9
nx = 9
dims = [nt, ny, nx]
for seed in seeds:
    tempmodel= ModelSE3d1_Exp()
    tempmodel.load_state_dict(torch.load\
                              ('./out/20200429_v5_ModelSE3d1_Exp_Ploss_seed_'+str(seed)+'.pth'))
    tempmodel=tempmodel.to(device_cpu)
    conv3d_0=tempmodel.conv1.weight.cpu().data.numpy() #shape (16,2,8,9,9)
    conv3d_0=np.reshape(conv3d_0,(-1,nt,ny,nx))
    for ii in range(len(conv3d_0)):
        [conv1_ss,_]=mySVD(conv3d_0[ii], dims)
        conv1_ss_s.append(conv1_ss)
conv1_ss_s=np.array(conv1_ss_s)
print (conv1_ss_s.shape)
conv1_ss_s=np.reshape(conv1_ss_s,(-1,width*height))
print (conv1_ss_s.shape)
#
for ii in range(len(conv1_ss_s)):
    fit_2dgaussian=Fit_2dGaussian(conv1_ss_s[ii],(width,height))
    fit_2dgaussian.fit()
    r2_s.append(fit_2dgaussian.cal_r2())
r2_s=np.array(r2_s)
print (np.median(r2_s))
print (np.mean(r2_s))
# Out:
# (320, 9, 9)
# (320, 81)
# /usr/local/lib/python3.5/dist-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 0.0
# 0.14035461316742798

# %%
# save svd results of example neuronal RFs
nt = 8 # time lag
ny = 28
nx = 28
dims = [nt, ny, nx]
#
#visualize final layer of model
tempmodel=ModelSE3d1_Exp()
tempmodel.load_state_dict(torch.load\
                    ('./out/20200429_v5_ModelSE3d1_Exp_Ploss_'+str(19)+'.pth'))
tempmodel=tempmodel.to(device_cpu)
RF_fl=vis_model_fl_3d(tempmodel,device_cpu,(1,2,8,28,28))
RF_fl_np=RF_fl.cpu().data.numpy() #output shape (50,2,28,28)
print (RF_fl_np.shape)
#nums_eg=np.arange(len(RF_fl_np))
#
#plot RFs
nums_eg=[63,3,78]  #np.arange(len(RF_fl_np))
nrows=len(nums_eg)
fig,axes = plt.subplots(nrows=nrows,ncols=3,figsize=(3,int(nrows/1.1)))
for ii in range(nrows):
    [sRF_UV, tRF_UV]=mySVD(RF_fl_np[nums_eg[ii],0], dims)
    [sRF_G, tRF_G]=mySVD(RF_fl_np[nums_eg[ii],1], dims)
    tempmax=np.max(np.abs([sRF_UV,sRF_G]))
    axes[ii,0].imshow(sRF_UV,vmin=-tempmax,vmax=tempmax,cmap='bwr')
    axes[ii,0].set_xticks([])
    axes[ii,0].set_yticks([])
    axes[ii,0].set_ylabel('%d' %(nums_eg[ii]))
    axes[ii,1].imshow(sRF_G,vmin=-tempmax,vmax=tempmax,cmap='bwr')
    axes[ii,1].set_xticks([])
    axes[ii,1].set_yticks([])
    axes[ii,2].plot(tRF_G,color='g',linestyle='-')
    axes[ii,2].plot(tRF_UV,color='purple',linestyle='-')
    axes[ii,2].axhline(y=0,color='k',linestyle=':')
    axes[ii,2].spines['left'].set_visible(False)
    axes[ii,2].spines['bottom'].set_visible(False)
    axes[ii,2].spines['right'].set_visible(False)
    axes[ii,2].spines['top'].set_visible(False)
    axes[ii,2].set_xticks([])
    axes[ii,2].set_yticks([])
axes[0,0].set_title('UV')
axes[0,1].set_title('G')
plt.tight_layout()
# Out:
# (96, 2, 8, 28, 28)

# %%
#plot prediction results for example neurons
tempmodel=ModelSE3d1_Exp()
tempmodel.load_state_dict(torch.load\
                    ('./out/20200429_v5_ModelSE3d1_Exp_Ploss_'+str(19)+'.pth'))
tempmodel=tempmodel.to(device_cpu)
tempmodel=tempmodel.eval()
(x,y)=test_loader
x=torch.from_numpy(x).float()
b_x = x.to(device_cpu) 
with torch.no_grad():
    encoded = tempmodel(b_x)
encoded_np=encoded.cpu().data.numpy()
encoded_np=encoded_np[7:,:] #use_pad0_sti=False
y=y[7:,:] #use_pad0_sti=False
#
nums_eg=[63,3,78] 
nrows=len(nums_eg)
#nrows=encoded_np.shape[1]
testccs=np.zeros((nrows))
testpVs=np.zeros((nrows))
fig,axes=plt.subplots(nrows=nrows,ncols=1,figsize=(2,int(nrows/1.1)))
for ii in range(nrows):
    testcc,testpvalue=pearsonr(encoded_np[:,nums_eg[ii]], y[:,nums_eg[ii]])
    testccs[ii]=testcc
    testpVs[ii]=testpvalue
    axes[ii].plot(y[:,nums_eg[ii]],color='gray',linestyle='-',label='Target')
    axes[ii].plot(encoded_np[:,nums_eg[ii]],color='k',linestyle='-',label='Predict')
    if ii == 0:
        axes[ii].legend(loc='best',frameon=False)
        #axes[ii].set_title('UVGnoise_30Hz')
    #axes[ii].set_title('Neuron: {:}, CC: {:.2f}, p: {:.2f}'.format(ii,testcc,testpvalue))
    axes[ii].spines['left'].set_visible(False)
    axes[ii].spines['bottom'].set_visible(False)
    axes[ii].spines['right'].set_visible(False)
    axes[ii].spines['top'].set_visible(False)
    axes[ii].set_xticks([])
    axes[ii].set_yticks([])
    axes[ii].set_xlabel('CC: %.2f, pV: %.2f' %(testcc,testpvalue))
    axes[ii].set_ylabel('%d' %(nums_eg[ii]))
plt.tight_layout()
