# %% [markdown]
# Semi-supervised learning.
# Encoding-past CAE network.
# Use 3d spatio-temporal conv kernels.

# %%
import torch
import torch.nn as nn
import torch.utils.data as Data
import torchvision
from torch.nn import functional as F
from torch.autograd import Variable

import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set(color_codes=True)
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import h5py
import cv2
from scipy.stats import pearsonr#Pearson correlation coefficient
from sklearn.decomposition import randomized_svd
from scipy.signal import find_peaks
import datetime
import time
#import winsound#sound alarm when code finishes, only in windows

from SemiNE3d.utils import *
from SemiNE3d.train import *
from chirpMB import *

# for auto-reloading external modules
# %load_ext autoreload
# %autoreload 2

# %%
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(1)
torch.backends.cudnn.deterministic=True
np.random.seed(1)
torch.manual_seed(1)    # reproducible
#
device=torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device_cpu=torch.device('cpu')
#device=torch.device('cpu')
EPOCH = 100
#BATCH_SIZE = 1000 #100
#LR = 0.05#original
LR=2e-4 # 1e-4
L2=0.0#L2=0.000001#L2 regularization

# %%
print (torch.cuda.is_available())
# Out:
# True

# %%
# for plot figures
plt.rcParams.update({'figure.max_open_warning': 0})
#Output matplotlib figure to SVG with text as text, not curves
plt.rcParams['svg.fonttype'] = 'none'
# axis spine
#use it like: adjust_spines(ax, ['left', 'bottom'])
def adjust_spines(ax, spines):
    for loc, spine in ax.spines.items():
        if loc in spines:
            spine.set_position(('outward', 2))  # outward by 2 points
            #spine.set_smart_bounds(True)
        else:
            spine.set_color('none')  # don't draw spine
    # turn off ticks where there is no spine
    if 'left' in spines:
        ax.yaxis.set_ticks_position('left')
    else:
        # no yaxis ticks
        ax.yaxis.set_ticks([])
    if 'bottom' in spines:
        ax.xaxis.set_ticks_position('bottom')
    else:
        # no xaxis ticks
        ax.xaxis.set_ticks([])

# %%
training_inputs = np.load('../data/fig5_suppl_training_inputs.npy')
training_set = np.load('../data/fig5_suppl_training_set.npy')
test_inputs = np.load('../data/fig5_suppl_test_inputs.npy')
test_set = np.load('../data/fig5_suppl_test_set.npy')
movie_bgr_h5 = np.load('../data/fig5_suppl_movie_bgr_h5.npy')

# %%
#split original training data into two parts, training loader: 2200, validation loader: 200
#make the dataset suitable for pytorch and semi-supervised learning
train_loader=[]
for ii in range(30):
    #neural data
    temp0=training_inputs[ii*440:ii*440+440] -0.5 #center the stimulus
    temp1=training_set[ii*440:ii*440+440] #660
    #natural image data
    temp2=movie_bgr_h5[ii*1200:ii*1200+1200] 
    temp=(temp0,temp1,temp2)
    #temp=(temp0,temp1)
    train_loader.append(temp)
#
temp0=training_inputs[13200:] -0.5 #center the stimulus
temp1=training_set[13200:]#200*200(neurons)
temp2=movie_bgr_h5[36000:39200]
#val_loader=(temp0,temp1)
val_loader=(temp0,temp1,temp2)
#
temp0=np.copy(test_inputs) -0.5 #center the stimulus
temp1=np.copy(test_set)#50*200(neurons)
temp2=movie_bgr_h5[39200:]
#test_loader=(temp0,temp1)
test_loader=(temp0,temp1,temp2)
#
print ('length of train_loader:')
print (len(train_loader))
print ('shape of train_loader[0][0]:')
print (train_loader[0][0].shape)
print ('shape of train_loader[0][1]:')
print (train_loader[0][1].shape)
print ('shape of train_loader[0][2]:')
print (train_loader[0][2].shape)
#
print ('shape of val_loader[0]:')
print (val_loader[0].shape)
print ('shape of val_loader[1]:')
print (val_loader[1].shape)
print ('shape of val_loader[2]:')
print (val_loader[2].shape)
#
print ('shape of test_loader[0]:')
print (test_loader[0].shape)
print ('shape of test_loader[1]:')
print (test_loader[1].shape)
print ('shape of test_loader[2]:')
print (test_loader[2].shape)
# Out:
# length of train_loader:
# 30
# shape of train_loader[0][0]:
# (440, 2, 30, 28, 28)
# shape of train_loader[0][1]:
# (440, 64)
# shape of train_loader[0][2]:
# (1200, 2, 30, 28, 28)
# shape of val_loader[0]:
# (1200, 2, 30, 28, 28)
# shape of val_loader[1]:
# (1200, 64)
# shape of val_loader[2]:
# (3200, 2, 30, 28, 28)
# shape of test_loader[0]:
# (300, 2, 30, 28, 28)
# shape of test_loader[1]:
# (300, 64)
# shape of test_loader[2]:
# (800, 2, 30, 28, 28)

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=1, ncols=10,figsize=(12.5,2.5))
for ii in range(10):
    axes[ii].imshow(train_loader[0][0][ii][0][0],cmap='gray',vmin=-0.5,vmax=0.5)
    axes[ii].grid(False)#axes[ii,jj].axis('tight')

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=5, ncols=1,figsize=(10,5))
for ii in range(5):
    axes[ii].plot(train_loader[0][1][:,ii])

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=1, ncols=10,figsize=(12.5,2.5))
for ii in range(10):
    axes[ii].imshow(test_loader[0][ii][0][0],cmap='gray',vmin=-0.5,vmax=0.5)
    axes[ii].grid(False)#axes[ii,jj].axis('tight')

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=5, ncols=1,figsize=(10,5))
for ii in range(5):
    axes[ii].plot(test_loader[1][:,ii])
    #axes[ii].grid(False)#axes[ii,jj].axis('tight')

# %%
fig, axes = plt.subplots(nrows=10, ncols=30,figsize=(15,10))
for ii in range(10):
    for jj in range(30):
        temp=np.zeros((28,28,3),np.uint8)
        temp[...,1:]=np.transpose(train_loader[10][2][ii][:,jj,:,:],(1,2,0))[...,::-1]
        axes[ii,jj].imshow(img_real2view(temp))
        axes[ii,jj].grid(False)#axes[ii,jj].axis('tight')

# %%
#preprocess: centered data
#sky_bg_mean_f   =(0.10539950580232095, 0.23792787064825932)
sky_bg_mean_f   =np.mean(movie_bgr_h5[:36000,:,:movie_bgr_h5.shape[2],:,:],axis=(0,2,3,4))/255.0
print(sky_bg_mean_f)
# Out:
# [0.19337444 0.2037598 ]

# %%
#function: visualize conv0 weights
def Vis_conv3d_0(conv3d_0,temptitle,save=False,filename=None): # conv3d_0.shape (16, 2, 8, 9, 9)
    (outd,_,_,_,_)=conv3d_0.shape
    fig, axes = plt.subplots(nrows=3, ncols=outd,figsize=(outd, 3))
    for jj in range(outd):
        nt = conv3d_0.shape[2] # time lag
        ny = 9
        nx = 9
        dims = [nt, ny, nx]
        [sRF_UV, tRF_UV]=mySVD(conv3d_0[jj,0], dims)
        [sRF_G, tRF_G]=mySVD(conv3d_0[jj,1], dims)
        tempmax=np.max(np.abs([sRF_UV,sRF_G]))
        axes[0,jj].imshow(sRF_UV,vmin=-tempmax,vmax=tempmax,cmap='bwr')
        axes[0,jj].set_xticks([])
        axes[0,jj].set_yticks([])
        axes[0,jj].set_title('%d' %(jj))
        axes[1,jj].imshow(sRF_G,vmin=-tempmax,vmax=tempmax,cmap='bwr')
        axes[1,jj].set_xticks([])
        axes[1,jj].set_yticks([])
        axes[2,jj].plot(tRF_G,color='g')
        axes[2,jj].plot(tRF_UV,color='purple')
        axes[2,jj].axhline(y=0,color='k')
        axes[2,jj].spines['left'].set_visible(False)
        axes[2,jj].spines['bottom'].set_visible(False)
        axes[2,jj].spines['right'].set_visible(False)
        axes[2,jj].spines['top'].set_visible(False)
        axes[2,jj].set_xticks([])
        axes[2,jj].set_yticks([])
        axes[0,0].set_ylabel(str(temptitle))
        axes[0,0].set_title('%d_UV' %(0))
    if save==True:
        fig.savefig(filename)

# %% [markdown]
# ##  <font color='red'>Model architecture</font>

# %%
class ModelSemiSL3d1_Conv3d_1(nn.Module):
    def __init__(self):
        super().__init__()
        #supervised
        self.numoffea=16 #number of features
        self.sizeoffea=20*20 #size of feature
        self.numofneuron=64 #number of neurons
        self.conv1=nn.Parameter(torch.zeros(self.numoffea,2,30,9,9))
        std=1. / np.sqrt(2*30*9*9)
        self.conv1.data.uniform_(-std, std)
        self.conv1_bias=nn.Parameter(torch.zeros(self.numoffea))
        self.conv1_bias.data.uniform_(-std, std)
        self.fc1=nn.Linear(self.numoffea*self.sizeoffea,self.numofneuron)
        #autoencoder
        #
        self.ae_dconv1 =nn.ConvTranspose2d(self.numoffea,2,kernel_size=9,stride=1,padding=4) #2,28*28
        self.ae_fc1    =nn.Linear(self.numoffea*28*28,self.numoffea*28*28)
        self.ae_dfc1   = nn.Linear(self.numoffea*28*28,self.numoffea*28*28)
        self.ae_encoder = nn.Sequential(
            #self.conv1, #16,28*28
            nn.ReLU(),
            Flatten3D(),
            self.ae_fc1,
            nn.ReLU(),
            #GaussianNoise(sigma=0)
        )
        self.ae_decoder = nn.Sequential(
            self.ae_dfc1,
            nn.ReLU(),
            Unflatten(-1,self.numoffea,28,28),
            self.ae_dconv1, #2,28*28
            nn.Tanh())
    #
    def forward(self, x, z):
        #supervised
        encoded = F.relu(F.conv3d(x, self.conv1, bias=self.conv1_bias,stride=1,padding=(0,0,0))) #16,20*20
        encoded = encoded.view(-1,self.numoffea*self.sizeoffea)
        encoded = torch.exp(self.fc1(encoded))
        #autoencoder
        #z          = z.unsqueeze(2) 
        ae_encoded = F.conv3d(z, self.conv1, bias=self.conv1_bias,stride=1,padding=(0,4,4))
        ae_encoded = self.ae_encoder(ae_encoded)
        ae_decoded = self.ae_decoder(ae_encoded)
        #ae_decoded = ae_decoded.squeeze(2) 
        return encoded, ae_encoded, ae_decoded
#for visualization of RFs
class ModelSemiSL3d1_Conv3d_1_copy(nn.Module):
    def __init__(self,conv1,conv1_bias,fc1_weight,fc1_bias):
        super().__init__()
        self.numoffea=16 #number of features
        self.sizeoffea=20*20 #size of feature
        self.numofneuron=64 #number of neurons
        self.conv1=nn.Parameter(torch.zeros(self.numoffea,2,30,9,9))
        std=1. / np.sqrt(2*30*9*9)
        self.conv1.data.uniform_(-std, std)
        self.conv1_bias=nn.Parameter(torch.zeros(self.numoffea))
        self.conv1_bias.data.uniform_(-std, std)
        self.fc1=nn.Linear(self.numoffea*self.sizeoffea,self.numofneuron)
        #
        self.conv1.data.copy_(conv1.clone().detach())
        self.conv1_bias.data.copy_(conv1_bias.clone().detach())
        self.fc1.weight.data.copy_(fc1_weight.clone().detach())
        self.fc1.bias.data.copy_(fc1_bias.clone().detach())
    #
    def forward(self, x):
        encoded = F.relu(F.conv3d(x, self.conv1, bias=self.conv1_bias,stride=1,padding=(0,0,0))) #16,20*20
        encoded = encoded.view(-1,self.numoffea*self.sizeoffea)
        encoded = torch.exp(self.fc1(encoded))
        return encoded

# %% [markdown]
# ##  <font color='red'>Different weights</font>

# %%
#Semi-supervised learning, ModelSemiSL2d1()
EPOCH=100
LR=3e-4 # 2e-4
alpha1s = [1e2] # [1e2]
alpha2s = [0] #not play a role
beta1s  =[1/16] # [1/4]
alpha3s =[1e3,  1e4,  1e5] # [1e3]
beta2s  =[1/64, 1/16, 1/4]
seeds   =[1]
lossweights=[0.8, 0.7, 0.6] # [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]
modelvalloss=np.zeros((len(alpha3s), len(beta2s), len(lossweights)))
modeltestloss=np.zeros((len(alpha3s), len(beta2s), len(lossweights)))
for ii in range(len(alpha3s)):
    for jj in range(len(beta2s)):
        for kk in range(len(lossweights)):
            torch.manual_seed(seeds[0])    # reproducible
            torch.cuda.manual_seed(seeds[0])
            tempmodel = ModelSemiSL3d1_Conv3d_1()
            optimizer = torch.optim.Adam(tempmodel.parameters(), lr=LR,weight_decay=0.0)
            model_train(tempmodel,train_loader,optimizer,device,EPOCH,loss_SemiSL,sky_bg_mean_f,val_loader,\
                    alpha1=alpha1s[0],alpha2=alpha2s[0],\
                    beta1=beta1s[0],alpha3=alpha3s[ii],beta2=beta2s[jj],lossweight=lossweights[kk],earlystop=True,verbose=True) 
        
            temp=model_val(tempmodel,val_loader,1,device_cpu,sky_bg_mean_f)
            print ('Val CC: {}'.format(temp))
            modelvalloss[ii,jj,kk]=temp
            temp,_=model_test(tempmodel,test_loader,device_cpu,sky_bg_mean_f,use_pad0_sti=False)
            #print (temp)
            modeltestloss[ii,jj,kk]=temp
            del tempmodel
            torch.cuda.empty_cache()
# Out:
# 2021-05-19 14:43:39.830164
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  0 | train loss: 0.8325
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  1 | train loss: 0.1997
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  2 | train loss: 0.1813
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  3 | train loss: 0.1807
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  4 | train loss: 0.1799
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  5 | train loss: 0.1793
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  6 | train loss: 0.1787
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  7 | train loss: 0.1782
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  8 | train loss: 0.1778
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  9 | train loss: 0.1773
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  10 | train loss: 0.1769
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  11 | train loss: 0.1765
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  12 | train loss: 0.1761
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  13 | train loss: 0.1757
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  14 | train loss: 0.1753
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  15 | train loss: 0.1750
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  16 | train loss: 0.1747
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  17 | train loss: 0.1743
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  18 | train loss: 0.1740
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  19 | train loss: 0.1737
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  20 | train loss: 0.1734
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  21 | train loss: 0.1731
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  22 | train loss: 0.1728
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  23 | train loss: 0.1726
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  24 | train loss: 0.1723
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  25 | train loss: 0.1721
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  26 | train loss: 0.1718
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  27 | train loss: 0.1715
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  28 | train loss: 0.1712
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  29 | train loss: 0.1709
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  30 | train loss: 0.1706
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  31 | train loss: 0.1702
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  32 | train loss: 0.1699
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  33 | train loss: 0.1696
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  34 | train loss: 0.1692
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  35 | train loss: 0.1689
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  36 | train loss: 0.1686
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  37 | train loss: 0.1682
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  38 | train loss: 0.1679
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  39 | train loss: 0.1675
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  40 | train loss: 0.1672
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  41 | train loss: 0.1669
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  42 | train loss: 0.1665
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  43 | train loss: 0.1662
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  44 | train loss: 0.1658
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  45 | train loss: 0.1655
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  46 | train loss: 0.1651
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  47 | train loss: 0.1647
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  48 | train loss: 0.1644
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  49 | train loss: 0.1640
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  50 | train loss: 0.1637
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  51 | train loss: 0.1633
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  52 | train loss: 0.1629
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  53 | train loss: 0.1625
# Epoch: 53 val loss: 0.2719, finish training!
# 2021-05-19 15:11:58.838418
# Val CC: 0.27187039569178234
# Overall pearson correlation coefficient:  0.4835969591315771  and p-value:  0.0
# 2021-05-19 15:12:09.624784
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  0 | train loss: 0.7358
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  1 | train loss: 0.1771
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  2 | train loss: 0.1608
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  3 | train loss: 0.1602
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  4 | train loss: 0.1593
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  5 | train loss: 0.1587
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  6 | train loss: 0.1582
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  7 | train loss: 0.1577
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  8 | train loss: 0.1572
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  9 | train loss: 0.1568
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  10 | train loss: 0.1564
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  11 | train loss: 0.1561
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  12 | train loss: 0.1556
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  13 | train loss: 0.1553
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  14 | train loss: 0.1550
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  15 | train loss: 0.1547
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  16 | train loss: 0.1544
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  17 | train loss: 0.1541
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  18 | train loss: 0.1539
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  19 | train loss: 0.1536
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  20 | train loss: 0.1533
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  21 | train loss: 0.1532
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  22 | train loss: 0.1529
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  23 | train loss: 0.1527
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  24 | train loss: 0.1524
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  25 | train loss: 0.1522
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  26 | train loss: 0.1520
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  27 | train loss: 0.1518
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  28 | train loss: 0.1515
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  29 | train loss: 0.1513
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  30 | train loss: 0.1510
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  31 | train loss: 0.1508
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  32 | train loss: 0.1505
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  33 | train loss: 0.1503
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  34 | train loss: 0.1500
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  35 | train loss: 0.1498
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  36 | train loss: 0.1495
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  37 | train loss: 0.1493
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  38 | train loss: 0.1489
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  39 | train loss: 0.1486
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  40 | train loss: 0.1484
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  41 | train loss: 0.1481
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  42 | train loss: 0.1478
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  43 | train loss: 0.1475
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  44 | train loss: 0.1472
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  45 | train loss: 0.1469
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  46 | train loss: 0.1466
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  47 | train loss: 0.1463
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  48 | train loss: 0.1460
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  49 | train loss: 0.1457
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  50 | train loss: 0.1454
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  51 | train loss: 0.1451
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  52 | train loss: 0.1449
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  53 | train loss: 0.1446
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  54 | train loss: 0.1443
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  55 | train loss: 0.1440
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  56 | train loss: 0.1437
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  57 | train loss: 0.1434
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  58 | train loss: 0.1432
# Epoch: 58 val loss: 0.2677, finish training!
# 2021-05-19 15:37:06.428185
# Val CC: 0.26768541769525506
# Overall pearson correlation coefficient:  0.4710040024936545  and p-value:  0.0
# 2021-05-19 15:37:19.032352
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  0 | train loss: 0.6392
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  1 | train loss: 0.1546
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  2 | train loss: 0.1409
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  3 | train loss: 0.1399
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  4 | train loss: 0.1390
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  5 | train loss: 0.1383
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  6 | train loss: 0.1377
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  7 | train loss: 0.1372
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  8 | train loss: 0.1367
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  9 | train loss: 0.1363
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  10 | train loss: 0.1360
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  11 | train loss: 0.1357
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  12 | train loss: 0.1352
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  13 | train loss: 0.1348
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  14 | train loss: 0.1346
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  15 | train loss: 0.1343
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  16 | train loss: 0.1340
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  17 | train loss: 0.1338
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  18 | train loss: 0.1335
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  19 | train loss: 0.1333
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  20 | train loss: 0.1331
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  21 | train loss: 0.1329
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  22 | train loss: 0.1352
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  23 | train loss: 0.1331
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  24 | train loss: 0.1326
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  25 | train loss: 0.1323
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  26 | train loss: 0.1321
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  27 | train loss: 0.1319
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  28 | train loss: 0.1317
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  29 | train loss: 0.1316
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  30 | train loss: 0.1313
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  31 | train loss: 0.1311
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  32 | train loss: 0.1309
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  33 | train loss: 0.1308
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  34 | train loss: 0.1306
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  35 | train loss: 0.1304
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  36 | train loss: 0.1302
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  37 | train loss: 0.1301
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  38 | train loss: 0.1298
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  39 | train loss: 0.1297
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  40 | train loss: 0.1293
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  41 | train loss: 0.1291
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  42 | train loss: 0.1289
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  43 | train loss: 0.1286
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  44 | train loss: 0.1284
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  45 | train loss: 0.1282
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  46 | train loss: 0.1280
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  47 | train loss: 0.1277
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  48 | train loss: 0.1275
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  49 | train loss: 0.1272
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  50 | train loss: 0.1270
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  51 | train loss: 0.1268
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  52 | train loss: 0.1266
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  53 | train loss: 0.1263
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  54 | train loss: 0.1260
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  55 | train loss: 0.1258
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  56 | train loss: 0.1256
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  57 | train loss: 0.1253
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  58 | train loss: 0.1251
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  59 | train loss: 0.1249
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  60 | train loss: 0.1247
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  61 | train loss: 0.1245
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  62 | train loss: 0.1243
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  63 | train loss: 0.1241
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  64 | train loss: 0.1239
# Epoch: 64 val loss: 0.2659, finish training!
# 2021-05-19 16:07:03.738557
# Val CC: 0.26594587505835293
# Overall pearson correlation coefficient:  0.45935386633762265  and p-value:  0.0
# 2021-05-19 16:07:17.656672
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  0 | train loss: 0.8385
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  1 | train loss: 0.2054
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  2 | train loss: 0.1874
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  3 | train loss: 0.1871
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  4 | train loss: 0.1865
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  5 | train loss: 0.1860
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  6 | train loss: 0.1854
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  7 | train loss: 0.1849
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  8 | train loss: 0.1845
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  9 | train loss: 0.1840
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  10 | train loss: 0.1836
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  11 | train loss: 0.1832
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  12 | train loss: 0.1828
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  13 | train loss: 0.1825
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  14 | train loss: 0.1821
# Model:  ModelSemiSL3d1_Conv3d_1 |Epoch:  15 | train loss: 0.1818

# %%
'''
alpha3s =[1e3,  1e4,  1e5] 
beta2s  =[1/64, 1/16, 1/4]
seeds   =[1]
lossweights=[0.8, 0.7, 0.6]
'''
print (np.max(modelvalloss))
print (np.argmax(modelvalloss))
print (modelvalloss)
print (np.max(modeltestloss))
print (np.argmax(modeltestloss))
print (modeltestloss)
# Out:
# 0.294365209777761
# 16
# [[[0.2718704  0.26768542 0.26594588]
#   [0.27544277 0.27836498 0.27795022]
#   [0.27335042 0.2760271  0.27936334]]
#
#  [[0.28765272 0.29204617 0.28539384]
#   [0.28812409 0.29354476 0.21871476]
#   [0.2870692  0.29436521 0.21595786]]
#
#  [[0.21502766 0.21485521 0.21379093]
#   [0.21560353 0.21533045 0.21485644]
#   [0.21542965 0.21512514 0.21539866]]]
# 0.5254090134451143
# 16
# [[[0.48359696 0.471004   0.45935387]
#   [0.49562085 0.49994221 0.5021559 ]
#   [0.48856421 0.49047128 0.49148354]]
#
#  [[0.5174401  0.52161425 0.49835075]
#   [0.51688346 0.52422251 0.35706001]
#   [0.51393795 0.52540901 0.34461125]]
#
#  [[0.33945186 0.33805625 0.34174502]
#   [0.34021965 0.33898336 0.33765194]
#   [0.33970797 0.3403551  0.33932736]]]

# %%
modelname=[3] # np.arange(1,10) #np.arange(1,3) [1,3,5,7]
plt.rcParams.update({'figure.max_open_warning': 0})
temptitle=1
for ii in range(len(modelname)):
    #print (ii)
    #print ('\n')
    #load model
    tempmodel= ModelSemiSL3d1_Conv3d_1()
    tempmodel.load_state_dict(torch.load\
                ('./out/20200219_v5_ModelSemiSL3d1_Conv3d_1_upandlow_seed_1_weight_'+str(modelname[ii])+'.pth'))
    tempmodel=tempmodel.to(device_cpu)
    #get parameters of model
    #conv3d_0=tempmodel.encoder[0].weight.cpu().data.numpy()
    conv3d_0=tempmodel.conv1.cpu().data.numpy()
    print (conv3d_0.shape)
    Vis_conv3d_0(conv3d_0,temptitle,save=False,\
        filename='out_result/20200219_v5_ModelSemiSL3d1_Conv3d_1_upandlow_weight_3_conv0_v5.svg')
    temptitle=temptitle+1
    torch.cuda.empty_cache()
# Out:
# (16, 2, 30, 9, 9)

# %% [markdown]
# ##  <font color='red'>after hyperparameter tuning</font>

# %%
EPOCH=100 
LR=3e-4 # 2e-4
alpha1s = [1e2]  # [1e2]
alpha2s = [0] #not play a role
beta1s  = [1/16] # [1/16]
alpha3s = [1e4]  # [1e4]
beta2s  = [1/4] # [1/16]
seeds   = [1]
lossweights=[0.9, 0.8, 0.7, 0.6, 0.5] # [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]
#modeltrainloss=[]
modelvalloss=[]
for ii in range(len(seeds)):
    for jj in range(len(lossweights)):
        seedname=str(ii+1) #start from first seed
        modelname=str(jj+1)
        torch.manual_seed(seeds[ii])    # reproducible
        torch.cuda.manual_seed(seeds[ii])
        tempmodel = ModelSemiSL3d1_Conv3d_1()
        optimizer = torch.optim.Adam(tempmodel.parameters(), lr=LR,weight_decay=0.0)
        model_train(tempmodel,train_loader,optimizer,device,EPOCH,loss_SemiSL,sky_bg_mean_f,val_loader,\
                    alpha1=alpha1s[0],alpha2=alpha2s[0],\
                    beta1=beta1s[0],alpha3=alpha3s[0],beta2=beta2s[0],lossweight=lossweights[jj],earlystop=True,verbose=False) 
        #modeltrainloss.append(temp)
        #
        torch.save(tempmodel.state_dict(),\
            './out/20200219_v5_ModelSemiSL3d1_Conv3d_1_upandlow_seed_'+seedname+'_weight_'+modelname+'.pth')
        temp=model_val(tempmodel,val_loader,1,device_cpu,sky_bg_mean_f)
        modelvalloss.append(temp)
        del tempmodel
        torch.cuda.empty_cache()
# Out:
# 2021-05-20 22:07:04.967798
# Epoch: 55 val loss: 0.2789, finish training!
# 2021-05-20 22:43:18.217440
# 2021-05-20 22:43:33.864599

# %%
modelvalloss=np.zeros((10,5)) # 10 seeds x 5 weights
for ii in range(modelvalloss.shape[0]):
    seed_str=str(ii+1)
    for jj in range(modelvalloss.shape[1]):
        weight_str=str(jj+1)
        tempmodel = ModelSemiSL3d1_Conv3d_1()
        tempmodel.load_state_dict(torch.load\
            ('./out/20200219_v5_ModelSemiSL3d1_Conv3d_1_upandlow_seed_'+seed_str+'_weight_'+weight_str+'.pth'))
        tempmodel=tempmodel.to(device_cpu)
        temp=model_val(tempmodel,val_loader,1,device_cpu,sky_bg_mean_f)
        modelvalloss[ii,jj]=temp
print (modelvalloss)
print (np.mean(modelvalloss,axis=0))
# Out:
# [[0.27895085 0.2870692  0.29436521 0.21595786 0.21433579]
#  [0.27373661 0.28128554 0.29338229 0.21671668 0.21427672]
#  [0.27396962 0.28205099 0.29095547 0.21755491 0.21467336]
#  [0.27628369 0.28363996 0.29292599 0.21578397 0.214549  ]
#  [0.27861071 0.28451564 0.2906102  0.21815737 0.21482015]
#  [0.27633185 0.28409167 0.29348533 0.21701584 0.2145715 ]
#  [0.27949032 0.28536054 0.29301134 0.2182255  0.21477744]
#  [0.2761356  0.28382001 0.29432754 0.21824603 0.21481715]
#  [0.27662875 0.28454068 0.29424355 0.21815416 0.21471998]
#  [0.2752494  0.2827174  0.29319625 0.21586708 0.21460088]]
# [0.27653874 0.28390916 0.29305032 0.21716794 0.2146142 ]

# %%
#test model
modeltestloss=[]
for ii in range(10):
    modelname=str(ii+1)
    tempmodel = ModelSemiSL3d1_Conv3d_1()
    tempmodel.load_state_dict(torch.load\
        ('./out/20200219_v5_ModelSemiSL3d1_Conv3d_1_upandlow_seed_'+modelname+'_weight_3'+'.pth'))
    tempmodel=tempmodel.to(device_cpu)
    CC,_=model_test(tempmodel,test_loader,device_cpu,sky_bg_mean_f,use_pad0_sti=False)
    modeltestloss.append(CC)

torch.cuda.empty_cache()
modeltestloss=np.array(modeltestloss)
print (modeltestloss)
print (np.mean(modeltestloss))
# Out:
# Overall pearson correlation coefficient:  0.5254090134451143  and p-value:  0.0
# Overall pearson correlation coefficient:  0.529359260889282  and p-value:  0.0
# Overall pearson correlation coefficient:  0.5285566497948181  and p-value:  0.0
# Overall pearson correlation coefficient:  0.530785130177458  and p-value:  0.0
# Overall pearson correlation coefficient:  0.5246424157082376  and p-value:  0.0
# Overall pearson correlation coefficient:  0.5291664836095578  and p-value:  0.0
# Overall pearson correlation coefficient:  0.527773197124613  and p-value:  0.0
# Overall pearson correlation coefficient:  0.5287590550132296  and p-value:  0.0
# Overall pearson correlation coefficient:  0.5273389237040897  and p-value:  0.0
# Overall pearson correlation coefficient:  0.5293455809508283  and p-value:  0.0
# [0.52540901 0.52935926 0.52855665 0.53078513 0.52464242 0.52916648
#  0.5277732  0.52875906 0.52733892 0.52934558]
# 0.5281135710417229

# %%
#save CCs for HNE with natural, pha-scr, noise
def model_test_save(model,data,device,use_pad0_sti=True):
    model=model.to(device)
    model=model.eval()
    (x,y,z)=data
    x=torch.from_numpy(x).float()
    b_x = x.to(device)
    z=z/255.0
    z[:,0,:,:,:]=z[:,0,:,:,:]-sky_bg_mean_f[0]
    z[:,1,:,:,:]=z[:,1,:,:,:]-sky_bg_mean_f[1]
    if 'Conv3d_1' in model.__class__.__name__:
        #b_z = torch.from_numpy(z).float().to(device)
        b_z = torch.from_numpy(z[:,:,:-1,:,:]).float().to(device)
    elif 'Conv3d_2' in model.__class__.__name__:
        #b_z = torch.from_numpy(z).float().to(device)
        #b_z[:,:,-1,:,:]=0 # 7th frame is set to 0 after preprocessing
        b_z = torch.from_numpy(z[:,:,:-1,:,:]).float().to(device)
        b_z[:,:,-1,:,:]=0 # the last frame is set to 0 after preprocessing
    elif 'Conv3d_4' in model.__class__.__name__:
        b_z = torch.from_numpy(z[:,:,:z.shape[2]-1,:,:]).float().to(device)
    #
    with torch.no_grad():
        if 'Semi' in model.__class__.__name__:
            encoded,_,_ = model(b_x,b_z)
        else:
            encoded = model(b_x)
    encoded_np=encoded.cpu().data.numpy()
    if use_pad0_sti==False: # do not use reponses of 0-padding stimulus, here 7 because we use 8 time lags
        encoded_np=encoded_np[x.shape[2]-1:,:]
        y=y[x.shape[2]-1:,:]
    testccs=np.zeros((encoded_np.shape[1]))
    for ii in range(encoded_np.shape[1]):
        testccs[ii],testpvalue=pearsonr(encoded_np[:,ii], y[:,ii])
    print (np.median(testccs))
    return testccs
#upandlow
tempmodel= ModelSemiSL3d1_Conv3d_1()
tempmodel.load_state_dict(torch.load('./out/20200219_v5_ModelSemiSL3d1_Conv3d_1_upandlow_seed_1_weight_3'+'.pth'))
tempmodel=tempmodel.to(device_cpu)
CCs=model_test_save(tempmodel,test_loader,device_cpu,use_pad0_sti=False)
#print (CCs.shape)
#print (CCs)
# Out:
# 0.4695712173756251

# %%
# save svd results of example neuronal RFs
nt = 30 # time lag
ny = 28
nx = 28
dims = [nt, ny, nx]
#
#visualize final layer of model
tempmodel= ModelSemiSL3d1_Conv3d_1()
tempmodel.load_state_dict(torch.load('./out/20200219_v5_ModelSemiSL3d1_Conv3d_1_upandlow_seed_1_weight_3'+'.pth'))
tempmodel=tempmodel.to(device_cpu)
conv1  =tempmodel.conv1.data.clone().detach()
conv1_bias   =tempmodel.conv1_bias.data.clone().detach()
fc1_weight=tempmodel.fc1.weight.data.clone().detach()
fc1_bias  =tempmodel.fc1.bias.data.clone().detach()
tempmodel= ModelSemiSL3d1_Conv3d_1_copy(conv1,conv1_bias,fc1_weight,fc1_bias)
tempmodel=tempmodel.to(device_cpu)
RF_fl=vis_model_fl_3d(tempmodel,device_cpu,(1,2,nt,28,28))
RF_fl_np=RF_fl.cpu().data.numpy() #output shape (50,2,28,28)
print (RF_fl_np.shape)
#nums_eg=np.arange(len(RF_fl_np))
#
#plot RFs
nums_eg=[31,29,6]  # [31,29,55], [1,2,6]
nrows=len(nums_eg)
fig,axes = plt.subplots(nrows=nrows,ncols=3,figsize=(3,int(nrows/1.1)))
for ii in range(nrows):
    [sRF_UV, tRF_UV]=mySVD(RF_fl_np[nums_eg[ii],0], dims)
    [sRF_G, tRF_G]=mySVD(RF_fl_np[nums_eg[ii],1], dims)
    tempmax=np.max(np.abs([sRF_UV,sRF_G]))
    axes[ii,0].imshow(sRF_UV,vmin=-tempmax,vmax=tempmax,cmap='bwr')
    axes[ii,0].set_xticks([])
    axes[ii,0].set_yticks([])
    axes[ii,0].set_ylabel('%d' %(nums_eg[ii]))
    axes[ii,1].imshow(sRF_G,vmin=-tempmax,vmax=tempmax,cmap='bwr')
    axes[ii,1].set_xticks([])
    axes[ii,1].set_yticks([])
    axes[ii,2].plot(tRF_G,color='g',linestyle='-')
    axes[ii,2].plot(tRF_UV,color='purple',linestyle='-')
    axes[ii,2].axhline(y=0,color='k',linestyle=':')
    axes[ii,2].spines['left'].set_visible(False)
    axes[ii,2].spines['bottom'].set_visible(False)
    axes[ii,2].spines['right'].set_visible(False)
    axes[ii,2].spines['top'].set_visible(False)
    axes[ii,2].set_xticks([])
    axes[ii,2].set_yticks([])
axes[0,0].set_title('UV')
axes[0,1].set_title('G')
plt.tight_layout()
# Out:
# (64, 2, 30, 28, 28)

# %%
#plot prediction results for example neurons
tempmodel= ModelSemiSL3d1_Conv3d_1()
tempmodel.load_state_dict(torch.load('./out/20200219_v5_ModelSemiSL3d1_Conv3d_1_upandlow_seed_1_weight_3'+'.pth'))
tempmodel=tempmodel.to(device_cpu)
tempmodel=tempmodel.eval()
(x,y,z)=test_loader
x=torch.from_numpy(x).float()
b_x = x.to(device_cpu)
z=z/255.0
z[:,0,:,:,:]=z[:,0,:,:,:]-sky_bg_mean_f[0]
z[:,1,:,:,:]=z[:,1,:,:,:]-sky_bg_mean_f[1]
if 'Conv3d_1' in tempmodel.__class__.__name__:
    #b_z = torch.from_numpy(z).float().to(device)
    b_z = torch.from_numpy(z[:,:,:-1,:,:]).float().to(device_cpu)
elif 'Conv3d_2' in tempmodel.__class__.__name__:
    #b_z = torch.from_numpy(z).float().to(device)
    #b_z[:,:,-1,:,:]=0 # 7th frame is set to 0 after preprocessing
    b_z = torch.from_numpy(z[:,:,:-1,:,:]).float().to(device_cpu)
    b_z[:,:,-1,:,:]=0 # the last frame is set to 0 after preprocessing
elif 'Conv3d_4' in tempmodel.__class__.__name__:
    b_z = torch.from_numpy(z[:,:,:z.shape[2]-1,:,:]).float().to(device_cpu)

with torch.no_grad():
    encoded,_,_ = tempmodel(b_x,b_z)
encoded_np=encoded.cpu().data.numpy()
encoded_np=encoded_np[x.shape[2]-1:,:] #use_pad0_sti=False
y=y[x.shape[2]-1:,:] #use_pad0_sti=False
#
nums_eg=[31,29,6]  # [31,29,55], [1,2,6]
nrows=len(nums_eg)
#nrows=encoded_np.shape[1]
testccs=np.zeros((nrows))
testpVs=np.zeros((nrows))
fig,axes=plt.subplots(nrows=nrows,ncols=1,figsize=(2,int(nrows/1.1)))
for ii in range(nrows):
    testcc,testpvalue=pearsonr(encoded_np[:,nums_eg[ii]], y[:,nums_eg[ii]])
    testccs[ii]=testcc
    testpVs[ii]=testpvalue
    axes[ii].plot(y[:,nums_eg[ii]],color='gray',linestyle='-',label='Target')
    axes[ii].plot(encoded_np[:,nums_eg[ii]],color='red',linestyle='-',label='Predict')
    if ii == 0:
        axes[ii].legend(loc='best',frameon=False)
        #axes[ii].set_title('UVGnoise_30Hz')
    #axes[ii].set_title('Neuron: {:}, CC: {:.2f}, p: {:.2f}'.format(ii,testcc,testpvalue))
    axes[ii].spines['left'].set_visible(False)
    axes[ii].spines['bottom'].set_visible(False)
    axes[ii].spines['right'].set_visible(False)
    axes[ii].spines['top'].set_visible(False)
    axes[ii].set_xticks([])
    axes[ii].set_yticks([])
    axes[ii].set_xlabel('CC: %.2f, pV: %.2f' %(testcc,testpvalue))
    axes[ii].set_ylabel('%d' %(nums_eg[ii]))
plt.tight_layout()
