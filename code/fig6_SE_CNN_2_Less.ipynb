# %% [markdown]
# Use 3d spatio-temporal conv kernels.

# %%
import torch
import torch.nn as nn
import torch.utils.data as Data
import torchvision
from torch.nn import functional as F
from torch.autograd import Variable

import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set(color_codes=True)
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import h5py
import cv2
from scipy.stats import pearsonr#Pearson correlation coefficient
from sklearn.decomposition import randomized_svd
from scipy.signal import find_peaks
import scipy.optimize as opt
import pandas as pd
#import tensorly as tl#use tensorly to do tensor decompostion
#from tensorly.decomposition import parafac
#tl.set_backend('numpy') # or any other backend

import datetime
import time
#import winsound#sound alarm when code finishes, only in windows

# for auto-reloading external modules
# %load_ext autoreload
# %autoreload 2

# %%
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(1)

torch.backends.cudnn.deterministic=True
np.random.seed(1)
torch.manual_seed(1)    # reproducible

# %%
# for plot figures
plt.rcParams.update({'figure.max_open_warning': 0})
#Output matplotlib figure to SVG with text as text, not curves
plt.rcParams['svg.fonttype'] = 'none'
# axis spine
#use it like: adjust_spines(ax, ['left', 'bottom'])
def adjust_spines(ax, spines):
    for loc, spine in ax.spines.items():
        if loc in spines:
            spine.set_position(('outward', 2))  # outward by 2 points
            #spine.set_smart_bounds(True)
        else:
            spine.set_color('none')  # don't draw spine
    # turn off ticks where there is no spine
    if 'left' in spines:
        ax.yaxis.set_ticks_position('left')
    else:
        # no yaxis ticks
        ax.yaxis.set_ticks([])
    if 'bottom' in spines:
        ax.xaxis.set_ticks_position('bottom')
    else:
        # no xaxis ticks
        ax.xaxis.set_ticks([])

# %%
training_inputs = np.load('../data/fig6_training_inputs.npy')
training_set = np.load('../data/fig6_training_set.npy')
test_inputs = np.load('../data/fig6_test_inputs.npy')
test_set = np.load('../data/fig6_test_set.npy')

# %%
#split original training data into two parts, training loader: 2200, validation loader: 200
#make the dataset suitable for pytorch
train_loader=[]
for ii in range(0,2200,110):
    temp0=training_inputs[ii:ii+110] -0.5 #center the stimulus
    temp1=training_set[ii:ii+110]#100*200(neurons)
    temp=(temp0,temp1)
    train_loader.append(temp)

temp0=training_inputs[2200:] -0.5 #center the stimulus
temp1=training_set[2200:]#200*200(neurons)
val_loader=(temp0,temp1)

temp0=np.copy(test_inputs) -0.5 #center the stimulus
temp1=np.copy(test_set)#50*200(neurons)
test_loader=(temp0,temp1)

print ('length of train_loader:')
print (len(train_loader))
print ('shape of train_loader[0][0]:')
print (train_loader[0][0].shape)
print ('shape of train_loader[0][1]:')
print (train_loader[0][1].shape)
print ('shape of val_loader[0]:')
print (val_loader[0].shape)
print ('shape of val_loader[1]:')
print (val_loader[1].shape)
print ('shape of test_loader[0]:')
print (test_loader[0].shape)
print ('shape of test_loader[1]:')
print (test_loader[1].shape)
# Out:
# length of train_loader:
# 20
# shape of train_loader[0][0]:
# (110, 2, 8, 28, 28)
# shape of train_loader[0][1]:
# (110, 427)
# shape of val_loader[0]:
# (200, 2, 8, 28, 28)
# shape of val_loader[1]:
# (200, 427)
# shape of test_loader[0]:
# (50, 2, 8, 28, 28)
# shape of test_loader[1]:
# (50, 427)

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=1, ncols=10,figsize=(12.5,2.5))
for ii in range(10):
    axes[ii].imshow(train_loader[0][0][ii][0][0],cmap='gray',vmin=-0.5,vmax=0.5)
    axes[ii].grid(False)#axes[ii,jj].axis('tight')

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=5, ncols=1,figsize=(10,5))
for ii in range(5):
    axes[ii].plot(train_loader[0][1][:,ii])

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=1, ncols=10,figsize=(12.5,2.5))
for ii in range(10):
    axes[ii].imshow(test_loader[0][ii][0][0],cmap='gray',vmin=-0.5,vmax=0.5)
    axes[ii].grid(False)#axes[ii,jj].axis('tight')

# %%
#visualize everything after making train and test loader
fig, axes = plt.subplots(nrows=5, ncols=1,figsize=(10,5))
for ii in range(5):
    axes[ii].plot(test_loader[1][:,ii])
    #axes[ii].grid(False)#axes[ii,jj].axis('tight')

# %%
#some help function
def bce_loss(input, target):
    """
    Numerically stable version of the binary cross-entropy loss function.

    As per https://github.com/pytorch/pytorch/issues/751
    See the TensorFlow docs for a derivation of this formula:
    https://www.tensorflow.org/api_docs/python/tf/nn/sigmoid_cross_entropy_with_logits

    Inputs:
    - input: PyTorch Tensor of shape (N, ) giving scores.
    - target: PyTorch Tensor of shape (N,) containing 0 and 1 giving targets.

    Returns:
    - A PyTorch Tensor containing the mean BCE loss over the minibatch of input data.
    """
    neg_abs = - input.abs()
    loss = input.clamp(min=0) - input * target + (1 + neg_abs.exp()).log()
    return loss.mean()

class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size() # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

class Unflatten(nn.Module):
    """
    An Unflatten module receives an input of shape (N, C*H*W) and reshapes it
    to produce an output of shape (N, C, H, W).
    """
    def __init__(self, N=-1, C=128, H=7, W=7):
        super(Unflatten, self).__init__()
        self.N = N
        self.C = C
        self.H = H
        self.W = W
    def forward(self, x):
        return x.view(self.N, self.C, self.H, self.W)

class Flatten3D(nn.Module):
    def forward(self, x):
        N, C, D, H, W = x.size() # read in N, C, D, H, W
        return x.view(N, -1)  # "flatten" the C *D* H * W values into a single vector per image

class Unflatten3D(nn.Module):
    """
    An Unflatten module receives an input of shape (N, C*D*H*W) and reshapes it
    to produce an output of shape (N, C, D,H, W).
    """
    def __init__(self, N=-1, C=128, D=7, H=7, W=7):
        super(Unflatten3D, self).__init__()
        self.N = N
        self.C = C
        self.D = D
        self.H = H
        self.W = W
    def forward(self, x):
        return x.view(self.N, self.C, self.D, self.H, self.W)
    
    
def initialize_weights(m):
    if isinstance(m, nn.Linear) or isinstance(m, nn.ConvTranspose2d):
        init.xavier_uniform_(m.weight.data)
def init_weights_Kaiming(m):
    if type(m) == nn.Linear or type(m) == nn.Conv3d or type(m) == nn.ConvTranspose3d\
    or type(m) == nn.Conv2d or type(m) == nn.ConvTranspose2d:
        #torch.nn.init.kaiming_normal_(m.weight)
        torch.nn.init.kaiming_uniform_(m.weight)

def loss_vae(recon_x, x, mu, logvar):
    tempN=x.shape[0]
    MSE = F.mse_loss(recon_x, x, reduction='sum')
    #BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction='sum')
    # see Appendix B from VAE paper:
    # Kingma and Welling. Auto-Encoding Variational Bayes. ICLR, 2014
    # https://arxiv.org/abs/1312.6114
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    #return BCE + KLD
    return (MSE + KLD)/(tempN*10*2*56*56)#batch size tempN, to be comparable with other ae variants loss

loss_mse = nn.MSELoss()
#loss_ssim = pytorch_ssim.SSIM(window_size=3)

#loss with L2 and L1 regularizer
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def loss_L2L1(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempN=x.shape[0]
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    L1loss=beta*F.l1_loss(beta_y,torch.zeros_like(beta_y),reduction='sum')
    return (MSE+L2loss+L1loss)/(tempN*10*2*56*56)#batch size tempN, to be comparable with other ae variants loss

#loss with L2 and L1 regularizer, version2
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def loss_L2L1v2(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempC, tempD, tempH, tempW =x.size()
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    B, C, D, H, W = beta_y.size() # Batch*channel*depth*height*width
    temp1=beta_y.view(B,C,-1)
    temp2=torch.norm(temp1,p=2,dim=2)
    temp3=torch.sum(torch.abs(temp2))
    L1loss=beta*temp3
    #return (MSE+L2loss+L1loss)/(tempB* 2*10*12*12)#batch size tempN, to be comparable with other ae variants loss
    return (MSE+L2loss+L1loss)/(tempB* tempC* tempD* tempH* tempW)#to be comparable with other ae variants loss

#loss with L2 and L1 regularizer, for supervised encoded
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def loss_L2L1_SE(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempN =x.size()
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    return (MSE+L2loss+L1loss)/(tempB* tempN)
#loss with L2 and L1 regularizer, for supervised encoded, Poisson loss
#something like loss = Poissonloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def Ploss_L2L1_SE(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempN =x.size()
    Ploss = F.poisson_nll_loss(recon_x, x,log_input=False, reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    return (Ploss+L2loss+L1loss)/(tempB* tempN)
def Ploss_L2L1_SE2(recon_x, x, alpha, alpha2, beta, alpha_x, alpha_x2, beta_y): #different convkernels with different L2 penalty
    tempB, tempN =x.size()
    Ploss = F.poisson_nll_loss(recon_x, x,log_input=False, reduction='sum')
    #
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    #
    l2temp2=0.0
    for temp in alpha_x2:
        l2temp2 = l2temp2 + temp.weight.norm(2)
    L2loss2=alpha2*l2temp2
    #
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    return (Ploss+L2loss+L2loss2+L1loss)/(tempB* tempN)
def Ploss_L2L1_SE_ST(recon_x, x, alpha1, alpha2, beta, alpha_x1, alpha_x2, beta_y): # for spatial and temporal separable model
    tempB, tempN =x.size()
    Ploss = F.poisson_nll_loss(recon_x, x,log_input=False, reduction='sum')
    l2temp=0.0
    for temp in alpha_x1:
        l2temp = l2temp+ temp.norm(2)
    l2temp2=0.0
    for temp in alpha_x2:
        l2temp2 = l2temp2+ temp.norm(2)
    L2loss=alpha1*l2temp+alpha2*l2temp2
    #
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    #return (Ploss+L2loss+L1loss)/(tempB* tempN)
    return Ploss+L2loss+L1loss
def loss_L1L1_SE(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempN =x.size()
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(1)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    return (MSE+L2loss+L1loss)/(tempB* tempN)

#loss with L2 and L1 regularizer, for supervised encoded, L2 for conv kernel smoothness
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def loss_L2lapL1_SE(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempN =x.size()
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    laplacian=torch.tensor([[0.5,1.0,0.5],[1.0,-6.0,1.0],[0.5,1.0,0.5]], requires_grad=False)#laplacian kernel
    for temp in alpha_x:
        #l2temp = l2temp+ temp.weight.norm(2)
        NN,CC=temp.weight.shape[0],temp.weight.shape[1]
        laplacians=laplacian.repeat(CC, CC, 1, 1).requires_grad_(False).to(device)
        temp2=F.conv2d(temp.weight,laplacians)
        l2temp = l2temp+ temp2.norm(2)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.weight.norm(1)
    L1loss=beta*l1temp
    return (MSE+L2loss+L1loss)/(tempB* tempN)

#visualize DNN
#https://github.com/chongyangma/cs231n/blob/master/assignments/assignment3/NetworkVisualization-PyTorch.ipynb
#https://blog.keras.io/how-convolutional-neural-networks-see-the-world.html
#https://jacobgil.github.io/deeplearning/filter-visualizations
#https://towardsdatascience.com/how-to-visualize-convolutional-features-in-40-lines-of-code-70b7d87b0030
#simple version: compute the gradient of the output channel wrt a blank image
#complex version: performa gradient ascend on the target channel, start with noise image
def vis_model_fl(model,device,xxshape):#visualize for final layer
    model=model.to(device)
    for param in model.parameters():
        param.requires_grad=False
    model=model.eval()
    (tempB,tempC,tempH,tempW)=xxshape#tempB should be equal to 1
    #xx=torch.randn((tempB,tempC,tempH,tempW),requires_grad=True)
    xx=torch.zeros((tempB,tempC,tempH,tempW),requires_grad=True)
    if xx.grad is not None:
        xx.grad.data.zero_()
    out=model(xx)
    outlen=out.shape[1]
    yy=torch.zeros(outlen,tempC,tempH,tempW)
    for ii in range(outlen):
        if xx.grad is not None:
            xx.grad.data.zero_()
        out=model(xx)
        temp=out[0,ii]
        temp.backward()
        yy[ii]=xx.grad.data
        #if xx.grad is not None:
        #    xx.grad.data.zero_()
    return yy
def vis_model_fl_3d(model,device,xxshape):#visualize for final layer
    model=model.to(device)
    for param in model.parameters():
        param.requires_grad=False
    model=model.eval()
    (tempB,tempC,tempD,tempH,tempW)=xxshape#tempB should be equal to 1
    #xx=torch.randn((tempB,tempC,tempH,tempW),requires_grad=True)
    xx=torch.zeros((tempB,tempC,tempD,tempH,tempW),requires_grad=True)
    if xx.grad is not None:
        xx.grad.data.zero_()
    out=model(xx)
    outlen=out.shape[1]
    yy=torch.zeros(outlen,tempC,tempD,tempH,tempW)
    for ii in range(outlen):
        if xx.grad is not None:
            xx.grad.data.zero_()
        out=model(xx)
        temp=out[0,ii]
        temp.backward()
        yy[ii]=xx.grad.data
        #if xx.grad is not None:
        #    xx.grad.data.zero_()
    return yy

#different preprocessing for different models
#x.shape: batchsize*10*2*56*56, x: bg, 1.0
#model: the model to be used, region: upper visual field (sky) or lower visual field (ground)
#region: sky or ground data
#pre_method: different preprocessing method, 'center': minus channel_mean, 'normalize': minus channel_mean then divided by
# the channel_std
def preprocess_np(x,model,pre_method,region):
    '''
    #some preprocessing if using model 'AutoEncoder3D_2'
    if model.__class__.__name__=='AutoEncoder3D_1':
        return x
    #for ae3D_2 or ae3D_3, subtrated by luminance mean value of each frame
    if model.__class__.__name__=='AutoEncoder3D_2' or \
        model.__class__.__name__=='AutoEncoder3D_3':
        for ii in range(x.shape[0]):
            for jj in range(x.shape[1]):
                for kk in range(x.shape[2]):
                    x[ii,jj,kk,:,:]=x[ii,jj,kk,:,:]-np.mean(x[ii,jj,kk,:,:])
        return x
    '''
    #for ae3D_4, subtrated by luminance mean value in color channel seperately across all frames
    #then divided by std. Because of memory proplem, this is done in make_dataset.py
    #std here actually is 'normalized' std
    if pre_method=='normalize' and region=='sky':
        x[:,0,:,:,:]=(x[:,0,:,:,:]-sky_bg_mean_f[0])/sky_bg_std_f[0]
        x[:,1,:,:,:]=(x[:,1,:,:,:]-sky_bg_mean_f[1])/sky_bg_std_f[1]
        return x
    if pre_method=='normalize' and region=='ground':
        x[:,0,:,:,:]=(x[:,0,:,:,:]-ground_bg_mean_f[0])/ground_bg_std_f[0]
        x[:,1,:,:,:]=(x[:,1,:,:,:]-ground_bg_mean_f[1])/ground_bg_std_f[1]
        return x
    #center the data, subtrated by luminance mean value in color channel seperately across all frames
    if pre_method=='center' and region=='sky':
        x[:,0,:,:,:]=x[:,0,:,:,:]-sky_bg_mean_f[0]
        x[:,1,:,:,:]=x[:,1,:,:,:]-sky_bg_mean_f[1]
        return x
    if pre_method=='center' and region=='ground':
        x[:,0,:,:,:]=x[:,0,:,:,:]-ground_bg_mean_f[0]
        x[:,1,:,:,:]=x[:,1,:,:,:]-ground_bg_mean_f[1]
        return x

#https://discuss.pytorch.org/t/where-is-the-noise-layer-in-pytorch/2887/4
'''
class GaussianNoise(nn.Module):
    def __init__(self, stddev=0.1):
        super().__init__()
        self.stddev = stddev

    def forward(self, din):
        if self.training:
            #return din + torch.autograd.Variable(torch.randn(din.size()).cuda() * self.stddev)
            return din + torch.autograd.Variable(torch.randn(din.size()).cuda() * self.stddev)
        return din
'''
class GaussianNoise(nn.Module):
    def __init__(self, sigma=0.1, is_relative_detach=True):
        super().__init__()
        self.sigma = sigma
        self.is_relative_detach = is_relative_detach
        #self.noise = torch.tensor(0).to(device)
        #self.noise = torch.randn_like(input, dtype=None, device=device, requires_grad=False)

    def forward(self, x):
        if self.training and self.sigma != 0:
            #scale = self.sigma * x.detach() if self.is_relative_detach else self.sigma * x
            #sampled_noise = self.noise.repeat(*x.size()).normal_() * scale
            sampled_noise = torch.randn(x.size(),requires_grad=False).to(device)* self.sigma
            x = x + sampled_noise
        return x

# %%
#function for training,(alpha,beta) for L2L1v2 regularizer
def model_train(model,data,optimizer,device,EPOCH,loss_func,valdata,alpha=None,beta=None,alpha2=None,\
                earlystop=False,verbose=True):
    print(datetime.datetime.now())
    #model=model.to(device)
    #model=model.train()
    loss=0.0
    trainlosses=np.zeros((EPOCH))
    vallosses  =np.zeros((EPOCH)) # save validation losses of all epochs until early stopping
    for epoch in range(EPOCH):
        model=model.to(device)
        model=model.train()
        for step, (x,y) in enumerate(data):
            #some preprocessing
            #x=preprocess_np(x,model,pre_method,region)
            x=torch.from_numpy(x).float()
            y=torch.from_numpy(y).float()
            b_x = x.to(device) 
            b_y = y.to(device)
            if 'dn' in model.__class__.__name__:
                b_x=b_x+0.05*torch.randn(b_x.size()).to(device)
                b_x=torch.clamp(b_x,min=-1.0,max=1.0)
            elif 'vae' in model.__class__.__name__:
                encoded, mu, logvar, decoded = model(b_x)
                loss = loss_func(decoded, b_y, mu, logvar)
            elif 'L2L1' in model.__class__.__name__:
                encoded = model(b_x)
                loss=loss_func(decoded, b_y,alpha,beta,[model.conv1],encoded)
            elif 'ST' in model.__class__.__name__: # spatial and temporal kernel separable
                encoded = model(b_x)
                loss=loss_func(encoded, b_y,alpha,alpha2,beta,[model.conv1_ss],[model.conv1_st],[model.fc1])
            else:
                encoded = model(b_x)
                loss=loss_func(encoded, b_y,alpha,beta,[model.conv1],[model.fc1])
            
            #last epoch to get the training loss, keep the same sample size as validation
            trainlosses[epoch]=trainlosses[epoch]+loss.detach().clone().cpu().data.numpy()
            #
            optimizer.zero_grad()               # clear gradients for this training step
            loss.backward()                     # backpropagation, compute gradients
            optimizer.step()                    # apply gradients
            #
            if step % 100 == 0 and verbose==True:
                print('Model: ',model.__class__.__name__,'|Epoch: ', epoch,\
                      '| train loss: %.4f' % loss.cpu().data.numpy())
        #one epoch done
        #scheduler.step()
        if epoch>20 and earlystop==True: # early stopping check after each epoch, use CC as a metric
            temploss=model_val(model,valdata,1,device)
            vallosses[epoch]=temploss
            if epoch-np.argmax(vallosses)>4: # >4
                break
        #test
        trainlosses[epoch] =trainlosses[epoch]/len(data)
        temploss=model_val(model,valdata,1,device)
        vallosses[epoch]=temploss
    print ('Epoch: {:} val loss: {:.4f}, finish training!'.format(epoch,vallosses[epoch]))
    print(datetime.datetime.now())
    return trainlosses,vallosses #semilosses #test
    #print ('finish training!')
    #print(datetime.datetime.now())
    #train_loss=train_loss/len(data) #train_loader_length
    #print ('Model: ',model.__class__.__name__,'|train loss: %.4f' % train_loss)
    #return train_loss
    #winsound.Beep(400, 3000)#sound alarm when code finishes, freq=400, duration=3000ms
    
#_=model_train(ae3D_4,'normalize',sky',train_loader_shuffle,optimizer,device,EPOCH,loss_mse)

# %%
#use the trained model to test the validation loss
#show one example results
#val_eg: the example used to show results
#val_num: the number of validation dataset, when using gpu, may have memory problem, then set it small
def model_val(model,data,val_eg,device,loss_func=None):
    model=model.to(device)
    model=model.eval()
    #    
    #mse as metric,compute validation loss
    #loss_mse = nn.MSELoss()
    (x,y)=data
    x=torch.from_numpy(x).float()
    #y=torch.from_numpy(y).float()
    b_x = x.to(device) 
    #b_y = y.to(device)
    with torch.no_grad():
        if 'dn' in model.__class__.__name__:
            b_x=b_x+0.05*torch.randn(b_x.size()).to(device)
            b_x=torch.clamp(b_x,min=-1.0,max=1.0)
        if 'vae' in model.__class__.__name__:
            encoded, mu, logvar, decoded = model(b_x)
            #val_loss = loss_func(decoded, b_y, mu, logvar)
        else:
            encoded = model(b_x)
    #CC as metric
    encoded_np=encoded.cpu().data.numpy()
    valcc,valpV=pearsonr(encoded_np.T.flatten(), y.T.flatten())
    if valpV>0.05:
        valcc=0
    #Poisson loss metric
    #y=torch.from_numpy(y).float()
    #b_y = y.to(device)
    #valcc = F.poisson_nll_loss(encoded, b_y,log_input=False, reduction='sum')
    
    #encoded_np=encoded.cpu().data.numpy()
    #valcc,_=pearsonr(encoded_np.flatten(), y.flatten())
    #print ('Model: ',model.__class__.__name__,'|validation cc: %.4f' % valcc)
    #show one example
    #fig,ax=plt.subplots(nrows=1, ncols=1,figsize=(10,2))
    #ax.plot(data[1][:,val_eg],color='r',label='Target')
    #ax.plot(encoded.cpu().data.numpy()[:,val_eg],color='g',label='Predict')
    #ax.legend(loc='best',fontsize=12)
    return valcc
  
#_=model_val(ae3D_4,'normalize','sky',val_loader_shuffle_sky,200,1000,device_cpu,loss_mse)

# %%
#function: visualize conv0 weights
def Vis_conv3d_0(conv3d_0,temptitle,save=False,filename=None): # conv3d_0.shape (16, 2, 8, 9, 9)
    (outd,_,_,_,_)=conv3d_0.shape
    fig, axes = plt.subplots(nrows=3, ncols=outd,figsize=(outd, 3))
    for jj in range(outd):
        nt = 8 # time lag
        ny = 9
        nx = 9
        dims = [nt, ny, nx]
        [sRF_UV, tRF_UV]=mySVD(conv3d_0[jj,0], dims)
        [sRF_G, tRF_G]=mySVD(conv3d_0[jj,1], dims)
        tempmax=np.max(np.abs([sRF_UV,sRF_G]))
        axes[0,jj].imshow(sRF_UV,vmin=-tempmax,vmax=tempmax,cmap='bwr')
        axes[0,jj].set_xticks([])
        axes[0,jj].set_yticks([])
        axes[0,jj].set_title('%d' %(jj))
        axes[1,jj].imshow(sRF_G,vmin=-tempmax,vmax=tempmax,cmap='bwr')
        axes[1,jj].set_xticks([])
        axes[1,jj].set_yticks([])
        axes[2,jj].plot(tRF_G,color='g')
        axes[2,jj].plot(tRF_UV,color='purple')
        axes[2,jj].axhline(y=0,color='k')
        axes[2,jj].spines['left'].set_visible(False)
        axes[2,jj].spines['bottom'].set_visible(False)
        axes[2,jj].spines['right'].set_visible(False)
        axes[2,jj].spines['top'].set_visible(False)
        axes[2,jj].set_xticks([])
        axes[2,jj].set_yticks([])
        axes[0,0].set_ylabel(str(temptitle))
        axes[0,0].set_title('%d_UV' %(0))
    if save==True:
        fig.savefig(filename)

# %%
#using pearson correlation as metric
def model_test(model,data,device,use_pad0_sti=True):
    model=model.to(device)
    model=model.eval()
    (x,y)=data
    x=torch.from_numpy(x).float()
    b_x = x.to(device) 
    encoded = model(b_x)
    encoded_np=encoded.cpu().data.numpy()
    if use_pad0_sti==False: # do not use reponses of 0-padding stimulus, here 7 because we use 8 time lags
        encoded_np=encoded_np[7:,:]
        y=y[7:,:]
    testcc,testpvalue=pearsonr(encoded_np.flatten(), y.flatten())
    #show the best example
    testccs=np.zeros(y.shape[1])
    encoded_np=encoded_np+1e-5 #in case all zeros
    for ii in range(len(testccs)):
        testccs[ii],_=pearsonr(encoded_np[:,ii], y[:,ii])
    testccs[np.isnan(testccs)] = 0 #nan to 0
    test_best=np.argmax(testccs)
    fig,ax=plt.subplots(nrows=1, ncols=1,figsize=(10,2))
    ax.plot(y[:,test_best],'o',color='r',linestyle='-',alpha=0.5,label='Target')
    ax.plot(encoded_np[:,test_best],'o',color='g',linestyle='-',alpha=0.5,label='Predict')
    ax.legend(loc='best',fontsize=12)
    print ('Overall pearson correlation coefficient: ',testcc, ' and p-value: ',testpvalue)
    return testcc,testpvalue
    
#model_test(ae3D_4,'normalize',sky',test_loader_shuffle,2000,device,loss_mse)

# %%
device=torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device_cpu=torch.device('cpu')
#device=torch.device('cpu')
# 超参数
EPOCH = 50
BATCH_SIZE = 100
#LR = 0.05#original
LR=0.0001
L2=0.0#L2=0.000001#L2 regularization

# %%
# save svd results of all neuronal RFs
nt = 8 # time lag
ny = 28
nx = 28
dims = [nt, ny, nx]
def mySVD(w, dims):
    """
    SVD for 3d or 2d kernels
    only apply to Gaussian or DOG kernel, the center RF is near the frame center
    """
    if len(dims) == 3:
        dims_tRF = dims[0]
        dims_sRF = dims[1:]
        w_old=np.copy(w)
        w=np.reshape(w,(dims_tRF, np.prod(dims_sRF)))
        # Data matrix X, centered X
        w=w-np.mean(w,axis=0)
        U, S, Vt = randomized_svd(w, 3)
        sRF = Vt[0].reshape(*dims_sRF)
        tRF = U[:, 0]
        #change the sign of sRF and tRF to map with 3d RFs, which is unpredicable in SVD
        '''
        tempcc,_=pearsonr(sRF.flatten(), w[-2])
        if tempcc<0:
            sRF = -1 * sRF
            tRF = -1 * tRF
        '''
        '''
        #keep sRF and w[-2] the same scale
        sRF = np.max(w[-2])/np.max(sRF) *sRF
        tRF = np.max(sRF)/np.max(w[-2]) *tRF
        '''
        '''
        tempscale=np.max(np.abs(w[-2]))/np.max(np.abs(sRF))
        sRF = tempscale *sRF
        neww=np.einsum('i,jk->ijk',tRF,sRF)
        tempscale=np.max(w)/np.max(neww)
        tRF = tempscale *tRF
        '''
        '''
        tempscale=np.max(np.abs(w[-2]))/np.max(np.abs(sRF))
        sRF = tempscale *sRF
        tRF = tempscale *tRF
        '''
        peaks, _ = find_peaks(np.abs(tRF)) #peak index
        if not peaks.size>0: # empty array, no peaks
            peak_close2t0=-2 #this may not be the best way to visualize a RF
        else:
            peak_close2t0=peaks[-1] #peak index close to time point 0
        w_old_peak_blur=cv2.GaussianBlur(w_old[peak_close2t0],(5,5),0)
        sRF_blur=cv2.GaussianBlur(sRF,(5,5),0)
        #sRF, same polarity and magnitude as w_ol
        tempcc,_=pearsonr(sRF_blur.flatten(), w_old_peak_blur.flatten())
        if tempcc<0:
            sRF = -1 * sRF
        tempscale=np.max(np.abs(w_old_peak_blur))/np.max(np.abs(sRF_blur))
        sRF = tempscale *sRF
        #tRF
        #tRF = tempscale *tRF
        #if -np.min(w_old_peak_blur)>np.max(w_old_peak_blur) and tRF[peak_close2t0]>0: #w_old: off, tRF: on
        #    tRF = -1 *tRF
        #elif -np.min(w_old_peak_blur)<np.max(w_old_peak_blur) and tRF[peak_close2t0]<0: #w_old: on, tRF: off
        #    tRF = -1 *tRF
        if tempcc<0:
            tRF = -1 * tRF
    else:
        sRF = w
        tRF = None
    return [sRF, tRF]

# %%
class Fit_2dGaussian():
    """
    fitting to 2d Gaussian and measure the fitting goodness
    input_data: input y-values, 1d array
    data_shape: raw data shape, tuple, e.g. for a 9x9 RF of a neuron: (9,9)
    
    if fail to fit, r2=0; if the parametre sigma_x or sigma_y > the size of the RF(9), then r2=0
    
    #https://stackoverflow.com/questions/21566379/fitting-a-2d-gaussian-function-using-scipy-optimize-curve-fit-valueerror-and-m
    #https://stackoverflow.com/questions/19189362/getting-the-r-squared-value-using-curve-fit
    #https://stackoverflow.com/questions/29003241/how-to-quantitatively-measure-goodness-of-fit-in-scipy
    
    test examples:
        #define model function and pass independant variables x and y as a list
        def twoD_Gaussian(xydata_tuple, amplitude, xo, yo, sigma_x, sigma_y, theta, offset):
            (x, y) = xydata_tuple 
            xo = float(xo)
            yo = float(yo)    
            a = (np.cos(theta)**2)/(2*sigma_x**2) + (np.sin(theta)**2)/(2*sigma_y**2)
            b = -(np.sin(2*theta))/(4*sigma_x**2) + (np.sin(2*theta))/(4*sigma_y**2)
            c = (np.sin(theta)**2)/(2*sigma_x**2) + (np.cos(theta)**2)/(2*sigma_y**2)
            g = offset + amplitude*np.exp( - (a*((x-xo)**2) + 2*b*(x-xo)*(y-yo) 
                            + c*((y-yo)**2)))
            return g.ravel()
        # Create x and y indices
        x = np.arange(9)
        x,y = np.meshgrid(x, x)
        #create data
        data = twoD_Gaussian((x, y), 2, 4, 4, 3, 5, 0, 1)
        data_noisy = data + 0.02*np.random.normal(size=data.shape)
        #
        fit_2dgaussian=Fit_2dGaussian(data_noisy,(9,9))
        fit_2dgaussian.fit()
        fit_2dgaussian.plot()
        print (fit_2dgaussian.cal_r2())
    
    """
    def __init__(self,input_data,data_shape):
        super().__init__()
        self.input_data=input_data
        self.data_shape=data_shape
        #
        self.sigma_thresh=max(self.data_shape) # threshold of sigma after fitting
        self.data_fitted=None
        self.fit_sucess=None # indicate the success of failure of fit
        self.popt=None
        self.large_sigma=None # indicate the sigma_x or sigma_y is too large
    
    def _twoD_Gaussian(self,xydata_tuple, amplitude, xo, yo, sigma_x, sigma_y, theta, offset):
        """define model function and pass independant variables x and y as a list.
        The output of twoD_Gaussian needs to be 1D
        """
        (x, y) = xydata_tuple 
        xo = float(xo)
        yo = float(yo)    
        a = (np.cos(theta)**2)/(2*sigma_x**2) + (np.sin(theta)**2)/(2*sigma_y**2)
        b = -(np.sin(2*theta))/(4*sigma_x**2) + (np.sin(2*theta))/(4*sigma_y**2)
        c = (np.sin(theta)**2)/(2*sigma_x**2) + (np.cos(theta)**2)/(2*sigma_y**2)
        g = offset + amplitude*np.exp( - (a*((x-xo)**2) + 2*b*(x-xo)*(y-yo) 
                            + c*((y-yo)**2)))
        return g.ravel()

    def _fitting_r2(self,y,y_fit):
        """
        Use coefficient of determination (aka the R2 value) to measure goodness-of-fit
        y refers to your input y-values, y_fit refers to your fitted y-values. Both are 1d arrays
    
        """
        # residual sum of squares
        ss_res = np.sum((y - y_fit) ** 2)
        # total sum of squares
        ss_tot = np.sum((y - np.mean(y)) ** 2)
        # r-squared
        r2 = 1 - (ss_res / ss_tot)
        return r2
    
    def fit(self):
        """
        fitting
        in case of failing to fit:
        #https://stackoverflow.com/questions/9172574/scipy-curve-fit-runtime-error-stopping-iteration
        """
        x=np.arange(self.data_shape[0])
        y=np.arange(self.data_shape[1])
        x,y = np.meshgrid(x, y)
        #
        initial_guess = (1,int(self.data_shape[0]/2),int(self.data_shape[1]/2),\
                         int(self.data_shape[0]/2),int(self.data_shape[1]/2),0,1)
        #popt, pcov = opt.curve_fit(self._twoD_Gaussian, (x, y), self.input_data, p0=initial_guess)
        #self.data_fitted = self._twoD_Gaussian((x, y), *popt)
        #self.fit_sucess=False
        try:
            popt,pcov = opt.curve_fit(self._twoD_Gaussian, (x, y), self.input_data, p0=initial_guess)
        except RuntimeError:
            self.fit_sucess=False
        else:
            self.popt=popt
            self.data_fitted = self._twoD_Gaussian((x, y), *popt)
            self.fit_sucess=True
            if self.popt[-3]>self.sigma_thresh or self.popt[-4]>self.sigma_thresh:
                self.large_sigma=True
        return None
    
    def plot(self):
        """
        Plot the fitting result
        """
        if self.fit_sucess==True:
            x=np.arange(self.data_shape[0])
            y=np.arange(self.data_shape[1])
            x,y = np.meshgrid(x, y)
            fig, ax = plt.subplots(1, 1)
            ax.imshow(np.reshape(self.input_data,self.data_shape))
            ax.contour(x, y, np.reshape(self.data_fitted,self.data_shape), 3, colors='w')
        elif self.fit_sucess==False:
            print ('Fail to fit, no plot!')
    
    def cal_r2(self):
        """
        calculate r2 - goodness of fitting
        """
        if self.fit_sucess==True:
            if self.large_sigma==True:
                return 0
            else:
                return self._fitting_r2(self.input_data,self.data_fitted)
        elif self.fit_sucess==False:
            return 0

# %% [markdown]
# ##  <font color='red'>ModelSE3d1_Exp, conv 3d</font>
# 16 conv kernels 9x9

# %%
class ModelSE3d1_Exp(nn.Module):
    def __init__(self):
        super().__init__()
        self.numoffea=16 #number of features
        self.sizeoffea=20*20 #size of feature
        self.numofneuron=427 #number of neurons
        self.conv1=nn.Conv3d(2,self.numoffea,kernel_size=(8,9,9),stride=1)#16,20*20
        self.fc1=nn.Linear(self.numoffea*self.sizeoffea,self.numofneuron)

    def forward(self, x):
        encoded = F.relu(self.conv1(x)) #16,20*20
        encoded = encoded.view(-1,self.numoffea*self.sizeoffea)
        encoded = torch.exp(self.fc1(encoded))
        return encoded

# %% [markdown]
# ### training example

# %%
#ModelSE3d1_Neu150_ST_Exp(), Poisson loss
EPOCH=100
LR = 3e-4 # 2e-4
batch_num = 12 # note that we use 8 in the paper
alphas=[0.0,1e1,1e2,1e3,1e4] # [0.0,1e0,1e1,1e2,1e3]
betas =[0.0,1/64,1/16,1/4,1] 
modeltrainloss=[]
modelvalloss=[]
for ii in range(len(alphas)):
    for jj in range(len(betas)):
        modelname=str(ii*len(betas)+jj+1)
        torch.manual_seed(1)    # reproducible
        torch.cuda.manual_seed(1)
        tempmodel = ModelSE3d1_Exp()
        optimizer = torch.optim.Adam(tempmodel.parameters(), lr=LR,weight_decay=0.0)
        temp=model_train(tempmodel,train_loader[:batch_num],optimizer,device,EPOCH,Ploss_L2L1_SE,valdata=val_loader,\
                             alpha=alphas[ii],beta=betas[jj],alpha2=None,earlystop=True,verbose=True)
        modeltrainloss.append(temp)
        torch.save(tempmodel.state_dict(),\
                       './out/20200429_v5_ModelSE3d1_Exp_Ploss_ventral_less_'+modelname+'.pth')
        temp=model_val(tempmodel,val_loader,1,device_cpu,loss_mse)
        modelvalloss.append(temp)
        #release gpu memory
        del tempmodel
        torch.cuda.empty_cache()
# Out:
# 2021-07-23 18:15:05.481025
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0082
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4400
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4387
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4228
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4194
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4175
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4151
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4131
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4109
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4083
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4056
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4026
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.3992
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.3953
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3910
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3860
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3804
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3741
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3671
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3597
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3519
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3442
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3368
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3300
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3238
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3182
# Epoch: 25 val loss: 0.2058, finish training!
# 2021-07-23 18:15:10.330483
# 2021-07-23 18:15:10.499670
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0138
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4459
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4446
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4287
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4253
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4234
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4210
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4190
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4167
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4142
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4115
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4085
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4051
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4013
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3970
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3921
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3866
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3804
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3736
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3663
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3588
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3513
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3441
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3375
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3314
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3260
# Epoch: 25 val loss: 0.2099, finish training!
# 2021-07-23 18:15:15.555061
# 2021-07-23 18:15:15.750495
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0309
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4636
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4622
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4462
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4426
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4404
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4377
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4354
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4328
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4300
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4271
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4238
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4203
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4164
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4121
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4073
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4020
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3962
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3899
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3832
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3763
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3694
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3627
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3565
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3507
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3456
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3409
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3367
# Epoch: 27 val loss: 0.2142, finish training!
# 2021-07-23 18:15:21.025519
# 2021-07-23 18:15:21.197347
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0990
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.5340
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.5299
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.5109
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.5033
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4968
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4897
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4830
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4762
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4694
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4628
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4565
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4506
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4450
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4399
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4351
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4306
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4263
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4222
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4181
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4140
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4099
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4058
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4017
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3976
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3935
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3895
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3856
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.3819
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.3783
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.3750
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.3719
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.3689
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.3662
# Epoch: 33 val loss: 0.2342, finish training!
# 2021-07-23 18:15:27.851556
# 2021-07-23 18:15:28.004138
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.3715
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.8058
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.7604
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.6951
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.6405
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5910
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5510
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.5252
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.5114
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.5015
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4932
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4863
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4805
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4756
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4713
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4675
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4642
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4611
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4583
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4558
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4533
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4511
# Epoch: 21 val loss: 0.2034, finish training!
# 2021-07-23 18:15:32.130193
# 2021-07-23 18:15:32.305380
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0087
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4405
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4392
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4233
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4199
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4180
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4156
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4136
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4114
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4089
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4063
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4033
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.3999
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.3962
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3919
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3870
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3816
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3754
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3686
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3613
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3536
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3460
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3386
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3318
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3256
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3200
# Epoch: 25 val loss: 0.2073, finish training!
# 2021-07-23 18:15:37.251278
# 2021-07-23 18:15:37.412154
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0143
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4464
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4451
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4292
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4258
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4239
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4215
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4195
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4173
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4148
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4121
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4092
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4058
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4021
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3979
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3931
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3877
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3817
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3751
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3679
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3605
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3531
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3459
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3393
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3332
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3278
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3229
# Epoch: 26 val loss: 0.2071, finish training!
# 2021-07-23 18:15:42.665848
# 2021-07-23 18:15:42.837172
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0314
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4641
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4627
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4467
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4430
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4409
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4382
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4359
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4334
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4306
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4277
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4245
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4210
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4172
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4130
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4083
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4031
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3975
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3913
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3847
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3779
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3711
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3645
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3583
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3526
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3474
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3427
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3386
# Epoch: 27 val loss: 0.2158, finish training!
# 2021-07-23 18:15:48.248660
# 2021-07-23 18:15:48.419021
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0995
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.5345
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.5304
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.5114
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.5038
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4973
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4903
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4836
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4768
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4701
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4635
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4573
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4514
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4459
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4408
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4361
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4317
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4275
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4234
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4194
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4154
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4114
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4074
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4033
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3993
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3953
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3914
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3875
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.3838
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.3804
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.3771
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.3740
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.3711
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.3684
# Epoch: 33 val loss: 0.2357, finish training!
# 2021-07-23 18:15:55.218654
# 2021-07-23 18:15:55.397202
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.3720
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.8064
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.7609
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.6956
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.6411
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5916
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5518
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.5260
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.5123
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.5024
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4942
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4874
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4817
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4768
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4725
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4688
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4655
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4625
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4597
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4572
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4548
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4526
# Epoch: 21 val loss: 0.2036, finish training!
# 2021-07-23 18:15:59.468471
# 2021-07-23 18:15:59.641368
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0131
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4453
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4434
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4275
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4241
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4223
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4200
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4181
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4161
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4139
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4115
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4090
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4062
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4030
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.3996
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.3957
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3913
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3863
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3808
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3746
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3680
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3611
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3542
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3476
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3413
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3357
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3306
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3260
# Epoch: 27 val loss: 0.2131, finish training!
# 2021-07-23 18:16:05.039727
# 2021-07-23 18:16:05.226202
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0188
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4512
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4494
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4335
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4301
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4282
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4259
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4240
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4220
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4198
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4175
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4149
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4121
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4090
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4056
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4018
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.3975
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.3926
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.3872
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3812
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3748
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3682
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3615
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3550
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3490
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3435
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3386
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3342
# Epoch: 27 val loss: 0.2173, finish training!
# 2021-07-23 18:16:10.644986
# 2021-07-23 18:16:10.822987
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0358
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4689
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4670
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4510
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4473
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4452
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4427
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4405
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4382
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4358
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4332
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4304
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4275
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4243
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4208
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4170
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4128
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4082
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4032
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.3977
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.3919
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.3859
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.3798
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.3739
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.3684
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.3633
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.3587
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.3546
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.3508
# Epoch: 28 val loss: 0.2262, finish training!
# 2021-07-23 18:16:16.415680
# 2021-07-23 18:16:16.592094
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.1039
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.5393
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.5347
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.5158
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.5082
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5019
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4951
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4886
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4821
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4757
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4695
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4637
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4582
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4532
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4487
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4445
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4407
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4371
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4337
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4303
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4271
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4238
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4205
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4171
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.4137
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.4104
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.4071
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.4038
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.4006
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.3976
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.3946
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.3919
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.3893
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.3869
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.3846
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.3825
# Epoch: 35 val loss: 0.2456, finish training!
# 2021-07-23 18:16:23.750944
# 2021-07-23 18:16:23.923441
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.3765
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.8112
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.7655
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.7006
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.6465
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5975
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5584
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.5334
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.5204
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.5111
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.5033
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4970
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4917
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4872
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4833
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4799
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4769
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4742
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4717
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4695
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4674
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4654
# Epoch: 21 val loss: 0.2048, finish training!
# 2021-07-23 18:16:28.052282
# 2021-07-23 18:16:28.225571
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0573
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4912
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4828
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4650
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4602
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4570
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4535
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4507
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4482
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4457
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4434
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4412
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4392
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4373
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4355
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4338
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4322
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4307
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4292
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4278
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4265
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4252
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4240
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4228
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.4217
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.4206
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.4196
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.4186
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.4176
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.4166
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.4156
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.4147
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.4137
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.4126
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.4116
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.4104
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.4092
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.4080
# Model:  ModelSE3d1_Exp |Epoch:  38 | train loss: 0.4066
# Model:  ModelSE3d1_Exp |Epoch:  39 | train loss: 0.4052
# Model:  ModelSE3d1_Exp |Epoch:  40 | train loss: 0.4037
# Model:  ModelSE3d1_Exp |Epoch:  41 | train loss: 0.4021
# Model:  ModelSE3d1_Exp |Epoch:  42 | train loss: 0.4004
# Model:  ModelSE3d1_Exp |Epoch:  43 | train loss: 0.3986
# Model:  ModelSE3d1_Exp |Epoch:  44 | train loss: 0.3967
# Model:  ModelSE3d1_Exp |Epoch:  45 | train loss: 0.3947
# Model:  ModelSE3d1_Exp |Epoch:  46 | train loss: 0.3926
# Model:  ModelSE3d1_Exp |Epoch:  47 | train loss: 0.3905
# Model:  ModelSE3d1_Exp |Epoch:  48 | train loss: 0.3882
# Model:  ModelSE3d1_Exp |Epoch:  49 | train loss: 0.3860
# Model:  ModelSE3d1_Exp |Epoch:  50 | train loss: 0.3837
# Model:  ModelSE3d1_Exp |Epoch:  51 | train loss: 0.3814
# Model:  ModelSE3d1_Exp |Epoch:  52 | train loss: 0.3792
# Epoch: 52 val loss: 0.2883, finish training!
# 2021-07-23 18:16:39.031634
# 2021-07-23 18:16:39.206072
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0630
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.4971
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.4888
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4711
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4663
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4631
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4597
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4570
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4545
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4521
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4498
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4477
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4458
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4439
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4422
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4406
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4391
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4376
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4362
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4349
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4336
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4324
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4313
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4302
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.4291
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.4281
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.4270
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.4260
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.4251
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.4241
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.4232
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.4222
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.4212
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.4202
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.4192
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.4181
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.4169
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.4157
# Model:  ModelSE3d1_Exp |Epoch:  38 | train loss: 0.4144
# Model:  ModelSE3d1_Exp |Epoch:  39 | train loss: 0.4130
# Model:  ModelSE3d1_Exp |Epoch:  40 | train loss: 0.4116
# Model:  ModelSE3d1_Exp |Epoch:  41 | train loss: 0.4101
# Model:  ModelSE3d1_Exp |Epoch:  42 | train loss: 0.4086
# Model:  ModelSE3d1_Exp |Epoch:  43 | train loss: 0.4069
# Model:  ModelSE3d1_Exp |Epoch:  44 | train loss: 0.4052
# Model:  ModelSE3d1_Exp |Epoch:  45 | train loss: 0.4035
# Model:  ModelSE3d1_Exp |Epoch:  46 | train loss: 0.4016
# Model:  ModelSE3d1_Exp |Epoch:  47 | train loss: 0.3998
# Model:  ModelSE3d1_Exp |Epoch:  48 | train loss: 0.3979
# Model:  ModelSE3d1_Exp |Epoch:  49 | train loss: 0.3959
# Model:  ModelSE3d1_Exp |Epoch:  50 | train loss: 0.3940
# Model:  ModelSE3d1_Exp |Epoch:  51 | train loss: 0.3921
# Model:  ModelSE3d1_Exp |Epoch:  52 | train loss: 0.3901
# Model:  ModelSE3d1_Exp |Epoch:  53 | train loss: 0.3882
# Epoch: 53 val loss: 0.2911, finish training!
# 2021-07-23 18:16:50.421494
# 2021-07-23 18:16:50.613790
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.0800
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.5149
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.5065
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.4888
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.4839
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.4807
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.4772
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.4744
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4718
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4694
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4671
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4649
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4629
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4610
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4593
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4576
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4561
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4546
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4532
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4518
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4506
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4493
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4481
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4469
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.4458
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.4447
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.4435
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.4424
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.4413
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.4402
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.4391
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.4381
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.4370
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.4359
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.4348
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.4337
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.4327
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.4316
# Model:  ModelSE3d1_Exp |Epoch:  38 | train loss: 0.4305
# Model:  ModelSE3d1_Exp |Epoch:  39 | train loss: 0.4295
# Model:  ModelSE3d1_Exp |Epoch:  40 | train loss: 0.4284
# Model:  ModelSE3d1_Exp |Epoch:  41 | train loss: 0.4273
# Model:  ModelSE3d1_Exp |Epoch:  42 | train loss: 0.4263
# Model:  ModelSE3d1_Exp |Epoch:  43 | train loss: 0.4252
# Model:  ModelSE3d1_Exp |Epoch:  44 | train loss: 0.4242
# Model:  ModelSE3d1_Exp |Epoch:  45 | train loss: 0.4232
# Model:  ModelSE3d1_Exp |Epoch:  46 | train loss: 0.4221
# Model:  ModelSE3d1_Exp |Epoch:  47 | train loss: 0.4211
# Model:  ModelSE3d1_Exp |Epoch:  48 | train loss: 0.4201
# Model:  ModelSE3d1_Exp |Epoch:  49 | train loss: 0.4190
# Model:  ModelSE3d1_Exp |Epoch:  50 | train loss: 0.4180
# Model:  ModelSE3d1_Exp |Epoch:  51 | train loss: 0.4170
# Model:  ModelSE3d1_Exp |Epoch:  52 | train loss: 0.4160
# Model:  ModelSE3d1_Exp |Epoch:  53 | train loss: 0.4149
# Model:  ModelSE3d1_Exp |Epoch:  54 | train loss: 0.4139
# Model:  ModelSE3d1_Exp |Epoch:  55 | train loss: 0.4129
# Model:  ModelSE3d1_Exp |Epoch:  56 | train loss: 0.4118
# Model:  ModelSE3d1_Exp |Epoch:  57 | train loss: 0.4108
# Model:  ModelSE3d1_Exp |Epoch:  58 | train loss: 0.4098
# Epoch: 58 val loss: 0.3025, finish training!
# 2021-07-23 18:17:02.781194
# 2021-07-23 18:17:02.875956
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.1482
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.5853
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.5748
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.5547
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.5465
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5399
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5330
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.5268
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.5209
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.5154
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.5104
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.5060
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.5022
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4991
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4964
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4942
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4921
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4903
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4886
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4870
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4854
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4839
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.4824
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.4809
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.4794
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.4779
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.4765
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.4750
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.4735
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.4721
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.4706
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.4691
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.4677
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.4662
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.4648
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.4634
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.4620
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.4606
# Model:  ModelSE3d1_Exp |Epoch:  38 | train loss: 0.4593
# Model:  ModelSE3d1_Exp |Epoch:  39 | train loss: 0.4580
# Model:  ModelSE3d1_Exp |Epoch:  40 | train loss: 0.4567
# Model:  ModelSE3d1_Exp |Epoch:  41 | train loss: 0.4555
# Model:  ModelSE3d1_Exp |Epoch:  42 | train loss: 0.4543
# Model:  ModelSE3d1_Exp |Epoch:  43 | train loss: 0.4532
# Model:  ModelSE3d1_Exp |Epoch:  44 | train loss: 0.4521
# Model:  ModelSE3d1_Exp |Epoch:  45 | train loss: 0.4511
# Model:  ModelSE3d1_Exp |Epoch:  46 | train loss: 0.4501
# Model:  ModelSE3d1_Exp |Epoch:  47 | train loss: 0.4491
# Model:  ModelSE3d1_Exp |Epoch:  48 | train loss: 0.4482
# Model:  ModelSE3d1_Exp |Epoch:  49 | train loss: 0.4474
# Model:  ModelSE3d1_Exp |Epoch:  50 | train loss: 0.4466
# Model:  ModelSE3d1_Exp |Epoch:  51 | train loss: 0.4458
# Model:  ModelSE3d1_Exp |Epoch:  52 | train loss: 0.4450
# Model:  ModelSE3d1_Exp |Epoch:  53 | train loss: 0.4443
# Model:  ModelSE3d1_Exp |Epoch:  54 | train loss: 0.4436
# Model:  ModelSE3d1_Exp |Epoch:  55 | train loss: 0.4430
# Model:  ModelSE3d1_Exp |Epoch:  56 | train loss: 0.4423
# Model:  ModelSE3d1_Exp |Epoch:  57 | train loss: 0.4417
# Model:  ModelSE3d1_Exp |Epoch:  58 | train loss: 0.4412
# Model:  ModelSE3d1_Exp |Epoch:  59 | train loss: 0.4406
# Model:  ModelSE3d1_Exp |Epoch:  60 | train loss: 0.4401
# Model:  ModelSE3d1_Exp |Epoch:  61 | train loss: 0.4396
# Model:  ModelSE3d1_Exp |Epoch:  62 | train loss: 0.4391
# Model:  ModelSE3d1_Exp |Epoch:  63 | train loss: 0.4386
# Model:  ModelSE3d1_Exp |Epoch:  64 | train loss: 0.4382
# Model:  ModelSE3d1_Exp |Epoch:  65 | train loss: 0.4377
# Model:  ModelSE3d1_Exp |Epoch:  66 | train loss: 0.4373
# Model:  ModelSE3d1_Exp |Epoch:  67 | train loss: 0.4369
# Model:  ModelSE3d1_Exp |Epoch:  68 | train loss: 0.4365
# Model:  ModelSE3d1_Exp |Epoch:  69 | train loss: 0.4361
# Model:  ModelSE3d1_Exp |Epoch:  70 | train loss: 0.4357
# Model:  ModelSE3d1_Exp |Epoch:  71 | train loss: 0.4354
# Model:  ModelSE3d1_Exp |Epoch:  72 | train loss: 0.4350
# Model:  ModelSE3d1_Exp |Epoch:  73 | train loss: 0.4347
# Model:  ModelSE3d1_Exp |Epoch:  74 | train loss: 0.4344
# Model:  ModelSE3d1_Exp |Epoch:  75 | train loss: 0.4340
# Model:  ModelSE3d1_Exp |Epoch:  76 | train loss: 0.4337
# Model:  ModelSE3d1_Exp |Epoch:  77 | train loss: 0.4334
# Model:  ModelSE3d1_Exp |Epoch:  78 | train loss: 0.4331
# Model:  ModelSE3d1_Exp |Epoch:  79 | train loss: 0.4328
# Model:  ModelSE3d1_Exp |Epoch:  80 | train loss: 0.4326
# Model:  ModelSE3d1_Exp |Epoch:  81 | train loss: 0.4323
# Model:  ModelSE3d1_Exp |Epoch:  82 | train loss: 0.4320
# Model:  ModelSE3d1_Exp |Epoch:  83 | train loss: 0.4317
# Model:  ModelSE3d1_Exp |Epoch:  84 | train loss: 0.4315
# Model:  ModelSE3d1_Exp |Epoch:  85 | train loss: 0.4312
# Model:  ModelSE3d1_Exp |Epoch:  86 | train loss: 0.4310
# Model:  ModelSE3d1_Exp |Epoch:  87 | train loss: 0.4307
# Model:  ModelSE3d1_Exp |Epoch:  88 | train loss: 0.4305
# Model:  ModelSE3d1_Exp |Epoch:  89 | train loss: 0.4302
# Model:  ModelSE3d1_Exp |Epoch:  90 | train loss: 0.4300
# Model:  ModelSE3d1_Exp |Epoch:  91 | train loss: 0.4297
# Model:  ModelSE3d1_Exp |Epoch:  92 | train loss: 0.4295
# Model:  ModelSE3d1_Exp |Epoch:  93 | train loss: 0.4293
# Model:  ModelSE3d1_Exp |Epoch:  94 | train loss: 0.4291
# Model:  ModelSE3d1_Exp |Epoch:  95 | train loss: 0.4288
# Model:  ModelSE3d1_Exp |Epoch:  96 | train loss: 0.4286
# Model:  ModelSE3d1_Exp |Epoch:  97 | train loss: 0.4284
# Epoch: 97 val loss: 0.3127, finish training!
# 2021-07-23 18:17:23.289248
# 2021-07-23 18:17:23.455867
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.4207
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.8579
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.8087
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.7452
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.6938
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.6491
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.6152
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.5966
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.5879
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.5815
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.5765
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.5724
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.5687
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.5651
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.5615
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.5577
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.5538
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.5496
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.5452
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.5408
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.5363
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.5318
# Epoch: 21 val loss: 0.2110, finish training!
# 2021-07-23 18:17:27.618732
# 2021-07-23 18:17:27.790839
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.4997
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.8386
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.7406
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.6650
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.6161
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5765
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5414
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.5060
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4586
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4352
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4290
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4250
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4237
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4232
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4230
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4229
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4228
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4227
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4227
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4227
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4227
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4227
# Epoch: 21 val loss: 0.2098, finish training!
# 2021-07-23 18:17:32.002906
# 2021-07-23 18:17:32.205346
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.5054
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.8446
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.7468
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.6714
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.6229
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.5836
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5489
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.5139
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4671
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4430
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4368
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4328
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4315
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4309
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4307
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4306
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4304
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4303
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4303
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4303
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4304
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4301
# Epoch: 21 val loss: 0.2098, finish training!
# 2021-07-23 18:17:36.223196
# 2021-07-23 18:17:36.378532
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.5224
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.8624
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.7654
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.6906
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.6428
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.6043
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.5706
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.5368
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.4914
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.4652
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.4585
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.4542
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.4524
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.4513
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.4507
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4501
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4495
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4490
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4485
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4480
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4476
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4471
# Epoch: 21 val loss: 0.2097, finish training!
# 2021-07-23 18:17:40.505000
# 2021-07-23 18:17:40.701356
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.5906
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 0.9336
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 0.8374
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.7627
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.7156
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.6784
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.6467
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.6160
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.5760
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.5357
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.5245
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.5172
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.5109
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.5064
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.5026
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.4991
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.4960
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.4931
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.4905
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.4879
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.4856
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.4834
# Epoch: 21 val loss: 0.2098, finish training!
# 2021-07-23 18:17:44.813349
# 2021-07-23 18:17:44.981791
# Model:  ModelSE3d1_Exp |Epoch:  0 | train loss: 1.8631
# Model:  ModelSE3d1_Exp |Epoch:  1 | train loss: 1.2105
# Model:  ModelSE3d1_Exp |Epoch:  2 | train loss: 1.0915
# Model:  ModelSE3d1_Exp |Epoch:  3 | train loss: 0.9879
# Model:  ModelSE3d1_Exp |Epoch:  4 | train loss: 0.9174
# Model:  ModelSE3d1_Exp |Epoch:  5 | train loss: 0.8674
# Model:  ModelSE3d1_Exp |Epoch:  6 | train loss: 0.8367
# Model:  ModelSE3d1_Exp |Epoch:  7 | train loss: 0.8147
# Model:  ModelSE3d1_Exp |Epoch:  8 | train loss: 0.7907
# Model:  ModelSE3d1_Exp |Epoch:  9 | train loss: 0.7615
# Model:  ModelSE3d1_Exp |Epoch:  10 | train loss: 0.7120
# Model:  ModelSE3d1_Exp |Epoch:  11 | train loss: 0.6650
# Model:  ModelSE3d1_Exp |Epoch:  12 | train loss: 0.6391
# Model:  ModelSE3d1_Exp |Epoch:  13 | train loss: 0.6217
# Model:  ModelSE3d1_Exp |Epoch:  14 | train loss: 0.6081
# Model:  ModelSE3d1_Exp |Epoch:  15 | train loss: 0.5971
# Model:  ModelSE3d1_Exp |Epoch:  16 | train loss: 0.5881
# Model:  ModelSE3d1_Exp |Epoch:  17 | train loss: 0.5803
# Model:  ModelSE3d1_Exp |Epoch:  18 | train loss: 0.5735
# Model:  ModelSE3d1_Exp |Epoch:  19 | train loss: 0.5675
# Model:  ModelSE3d1_Exp |Epoch:  20 | train loss: 0.5622
# Model:  ModelSE3d1_Exp |Epoch:  21 | train loss: 0.5573
# Model:  ModelSE3d1_Exp |Epoch:  22 | train loss: 0.5528
# Model:  ModelSE3d1_Exp |Epoch:  23 | train loss: 0.5487
# Model:  ModelSE3d1_Exp |Epoch:  24 | train loss: 0.5449
# Model:  ModelSE3d1_Exp |Epoch:  25 | train loss: 0.5413
# Model:  ModelSE3d1_Exp |Epoch:  26 | train loss: 0.5379
# Model:  ModelSE3d1_Exp |Epoch:  27 | train loss: 0.5347
# Model:  ModelSE3d1_Exp |Epoch:  28 | train loss: 0.5318
# Model:  ModelSE3d1_Exp |Epoch:  29 | train loss: 0.5290
# Model:  ModelSE3d1_Exp |Epoch:  30 | train loss: 0.5265
# Model:  ModelSE3d1_Exp |Epoch:  31 | train loss: 0.5241
# Model:  ModelSE3d1_Exp |Epoch:  32 | train loss: 0.5219
# Model:  ModelSE3d1_Exp |Epoch:  33 | train loss: 0.5199
# Model:  ModelSE3d1_Exp |Epoch:  34 | train loss: 0.5181
# Model:  ModelSE3d1_Exp |Epoch:  35 | train loss: 0.5163
# Model:  ModelSE3d1_Exp |Epoch:  36 | train loss: 0.5148
# Model:  ModelSE3d1_Exp |Epoch:  37 | train loss: 0.5133
# Model:  ModelSE3d1_Exp |Epoch:  38 | train loss: 0.5119
# Model:  ModelSE3d1_Exp |Epoch:  39 | train loss: 0.5106
# Model:  ModelSE3d1_Exp |Epoch:  40 | train loss: 0.5092
# Model:  ModelSE3d1_Exp |Epoch:  41 | train loss: 0.5081
# Model:  ModelSE3d1_Exp |Epoch:  42 | train loss: 0.5069
# Epoch: 42 val loss: 0.2108, finish training!
# 2021-07-23 18:17:53.549900

# %%
temp2=np.reshape(np.array(modelvalloss),(5,5))
print (temp2)
print (np.max(temp2))
# Out:
# [[0.20583426 0.20994246 0.21424557 0.23424655 0.20343737]
#  [0.20730801 0.20710391 0.21578086 0.23570757 0.20357572]
#  [0.21306213 0.21730845 0.22616545 0.24562231 0.2047693 ]
#  [0.28832406 0.29105768 0.30252524 0.31267613 0.21098107]
#  [0.20975775 0.20980477 0.20973683 0.2097874  0.21081778]]
# 0.31267612961481567
